# %%
import pandas as pd
import numpy as np

# %% [markdown]
# import country_converter as coco
#
# def clean_country_names(df, column='country', new_column='country_cleaned', manual_fixes=None):
#     # Step 1: Basic cleanup
#     df[column] = df[column].astype(str).str.strip()
#
#     # Step 2: Try to convert names safely
#     converted_names = []
#     for name in df[column]:
#         try:
#             converted = coco.convert(names=name, to='name_short', not_found=None)
#             converted_names.append(converted)
#         except Exception as e:
#             print(f"Error converting {name}: {e}")
#             converted_names.append(None)
#
#     # Step 3: Assign new column
#     df[new_column] = converted_names
#
#     # Step 4: Handle unmatched with manual fixes
#     if manual_fixes is not None:
#         df[new_column] = df[new_column].fillna(df[column].map(manual_fixes))
#
#     # Step 5: Optional feedback
#     unmatched = df[df[new_column].isna()]
#     if not unmatched.empty:
#         print("❗ Unmatched country names:", unmatched[column].unique())
#
#     return df

# %% [raw]
# manual_fixes = {
#     # Common alternate names → Standardized names
#     'Congo': 'Congo, Rep.',
#     'Congo (Brazzaville)': 'Congo, Rep.',
#     'Congo (Kinshasa)': 'Congo, Dem. Rep.',
#     'Ivory Coast': "Côte d'Ivoire",
#     'Syria': 'Syrian Arab Republic',
#     'Palestine': 'Palestine, State of',
#     'Cape Verde': 'Cabo Verde',
#     'Swaziland': 'Eswatini',
#     'Burma': 'Myanmar',
#     'Laos': "Lao People's Democratic Republic",
#     'Micronesia': 'Micronesia, Fed. Sts.',
#     'North Korea': "Korea, Dem. People's Rep.",
#     'South Korea': 'Korea, Rep.',
#     'Russia': 'Russian Federation',
#     'Vatican': 'Holy See',
#     'Vietnam': 'Viet Nam',
#
#     # Regions to optionally map or remove (not actual countries)
#     'Melanesia': None,
#     'Polynesia': None,
#     'Channel Islands': 'United Kingdom',  # or None if you prefer to drop
#
#     # Add more as needed...
# }
#
#
# pol = clean_country_names(pol, manual_fixes=manual_fixes)

# %%
child = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\Category_A\child_mortality_norm_withallpts_onlycountries.csv")

# %%
regions_to_drop = ['World']
child = child[~child['country'].isin(regions_to_drop)]

# %%
import country_converter as coco

child['country_c'] = coco.convert(names=child['country'], to='name_short', not_found=None)

# %%
child.columns
# Out:
# Index(['country', 'year', 'under_5yo_deaths', 'norm_deaths_pct',
#        'norm_with_pts', 'norm_pts_log5', 'country_c'],
#       dtype='object')

# %%
cook = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\Category_A\cook_withallpts_onlycountries.csv")

# %%
import country_converter as coco

cook['country_c'] = coco.convert(names=cook['country'], to='name_short', not_found=None)

# %%
cook.columns
# Out:
# Index(['country', 'year', 'clean_fuel_cooking', 'norm_clean_cooking',
#        'norm_with_points', 'norm_with_points_log5', 'country_c'],
#       dtype='object')

# %%
child_cook = pd.merge(cook, child, on = 'country_c', how = 'inner')
child_cook.shape
# Out:
# (191, 13)

# %%
child_cook['child_cook_pts'] = child_cook['norm_with_points_log5'] + child_cook['norm_pts_log5']

# %%
cc = child_cook[['country_c', 'child_cook_pts']]

# %%
elec = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\Category_A\electric_with_allpts_onlycountries.csv")

# %%
regions_to_drop = ['World']
child = child[~child['country'].isin(regions_to_drop)]

# %%
import country_converter as coco

# Manual fixes for unmatched or non-standard names
manual_fixes = {
    'Channel Islands': 'United Kingdom'
}

# Function to clean country names
def clean_country_names(df, column='country', new_column='country_cleaned', manual_fixes=None):
    df[column] = df[column].astype(str).str.strip()
    
    converted_names = []
    for name in df[column]:
        try:
            converted = coco.convert(names=name, to='name_short', not_found=None)
            converted_names.append(converted)
        except Exception:
            converted_names.append(None)
    
    df[new_column] = converted_names

    if manual_fixes:
        df[new_column] = df[new_column].fillna(df[column].map(manual_fixes))
    
    unmatched = df[df[new_column].isna()]
    if not unmatched.empty:
        print("❗ Unmatched country names:", unmatched[column].unique())

    return df

# ✅ Apply to the elec dataframe
elec = clean_country_names(elec, manual_fixes=manual_fixes)
# Out:
# Channel Islands not found in regex
# World not found in regex

# %%
elec.columns
# Out:
# Index(['country', 'year', 'access_electricity', 'norm_access_electricity',
#        'norm_with_pts', 'norm_pts_log5', 'country_cleaned'],
#       dtype='object')

# %%
food = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\Category_A\food_insecure_withallpts_onlycountries.csv")

# %%
import country_converter as coco

food['country_c'] = coco.convert(names=food['country'], to='name_short', not_found=None)
# Out:
# Melanesia not found in regex

# %%
elec_food = pd.merge(elec, food, on ='country_c', how = 'inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_100464\1288076222.py in ?()
# ----> 1 elec_food = pd.merge(elec, food, on ='country_c', how = 'inner')
#
# ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1306                     if lk is not None:
#    1307                         # Then we're either Hashable or a wrong-length arraylike,
#    1308                         #  the latter of which will raise
#    1309                         lk = cast(Hashable, lk)
# -> 1310                         left_keys.append(left._get_label_or_level_values(lk))
#    1311                         join_names.append(lk)
#    1312                     else:
#    1313                         # work-around for merge_asof(left_index=True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'country_c'

# %%
elec_food['elec_food'] = elec_food['norm_pts_log5'] + elec_food['norm_withpts_log5']

# %%
ef = elec_food[['country_c', 'elec_food']]

# %%
ccef = pd.merge(cc, ef, on = 'country_c', how = 'inner')

# %%
ccef['ccef_pts'] = ccef['child_cook_pts'] + ccef['elec_food']
ccef

# %%
life = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\Category_A\life_expect_withallpts_onlycountries.csv")

# %%
regions_to_drop = [
    'Northern America',
    'Oceania',
    'Europe',
    'Americas',
    'Asia',
    'Africa'
]

life = life[~life['country'].isin(regions_to_drop)]

# %%
import country_converter as coco

life['country_c'] = coco.convert(names=life['country'], to='name_short', not_found=None)

# %%
life['norm_life_expect'] = (life['norm_life_expect'] - life['norm_life_expect'].min()) / (life['norm_life_expect'].max() - life['norm_life_expect'].min())

# %%
life['life_expectpts_0412'] = life['norm_life_expect'] * 32

# %%
l = life[['country_c', 'life_expectpts_0412']]

# %%
mat = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\Category_A\maternal_mortality_withallpts_onlycountries.csv")

# %%
import country_converter as coco

mat['country_c'] = coco.convert(names=mat['country'], to='name_short', not_found=None)

# %%
mat = mat.sort_values('maternal_mortality', ascending = True)

# %%
mat['norm_maternal_mortality'] = 1 - (mat['norm_maternal_mortality'] - mat['norm_maternal_mortality'].min()) / (mat['norm_maternal_mortality'].max() - mat['norm_maternal_mortality'].min())

# %%
mat = mat.drop('norm_with_pts', axis = 1)

# %%
mat['norm_withpts_log5'] = mat['norm_maternal_mortality'] * 32

# %%
mat_life = pd.merge(mat, l, on = 'country_c', how = 'inner')
mat_life['mat_life'] = mat_life['norm_withpts_log5'] + mat_life['life_expectpts_0412']

# %%
ml = mat_life[['country_c', 'mat_life']]

# %%
ccefml = pd.merge(ccef, ml, on = 'country_c', how = 'inner')
ccefml
# Out:
#         country_c  child_cook_pts  elec_food    ccef_pts   mat_life
# 0           Italy       63.693271  64.000000  127.693271  61.667133
# 1     New Zealand       63.239312  59.634200  122.873512  60.814914
# 2           Japan       63.846636  63.428685  127.275320  62.727891
# 3           Chile       62.636079  58.936831  121.572910  59.144122
# 4         Romania       62.292543  58.468659  120.761201  55.192699
# ..            ...             ...        ...         ...        ...
# 142        Uganda       16.034681  14.079473   30.114154  39.685838
# 143  Sierra Leone        3.546433   6.387274    9.933707  26.858615
# 144       Liberia       15.241006   6.955785   22.196791  26.698411
# 145       Burundi       13.932234   6.845133   20.777368  30.869472
# 146   South Sudan        8.136494   0.000000    8.136494   4.685576
#
# [147 rows x 5 columns]

# %%
ccefml['ccefml_pts'] = ccefml['ccef_pts'] + ccefml['mat_life']
ccefml
# Out:
#         country_c  child_cook_pts  elec_food    ccef_pts   mat_life  \
# 0           Italy       63.693271  64.000000  127.693271  61.667133
# 1     New Zealand       63.239312  59.634200  122.873512  60.814914
# 2           Japan       63.846636  63.428685  127.275320  62.727891
# 3           Chile       62.636079  58.936831  121.572910  59.144122
# 4         Romania       62.292543  58.468659  120.761201  55.192699
# ..            ...             ...        ...         ...        ...
# 142        Uganda       16.034681  14.079473   30.114154  39.685838
# 143  Sierra Leone        3.546433   6.387274    9.933707  26.858615
# 144       Liberia       15.241006   6.955785   22.196791  26.698411
# 145       Burundi       13.932234   6.845133   20.777368  30.869472
# 146   South Sudan        8.136494   0.000000    8.136494   4.685576
#
#      ccefml_pts
# 0    189.360405
# 1    183.688426
# 2    190.003211
# 3    180.717032
# 4    175.953901
# ..          ...
# 142   69.799992
# 143   36.792322
# 144   48.895202
# 145   51.646840
# 146   12.822070
#
# [147 rows x 6 columns]

# %%
pol = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\Category_A\pollution_withallpts_onlycountries.csv")

# %%
pol['norm_pm_value'] = 1 - (pol['norm_pm_value'] - pol['norm_pm_value'].min()) / pol['norm_pm_value'].max() - pol['norm_pm_value'].min()

# %%
pol['norm_with_pts_log5'] = pol['norm_pm_value'] * 32

# %%
slums = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\Category_A\slums_norm_withbothpts_onlycountries.csv")

# %%
import country_converter as coco

slums['country_c'] = coco.convert(names=slums['country'], to='name_short', not_found=None)

# %%
import country_converter as coco

pol['country_c'] = coco.convert(names= pol['country'], to='name_short', not_found =None)

# %%
pol_slum = pd.merge(pol, slums, on ='country_c', how = 'inner')

# %%
ccefmlps = pd.merge(ccefml, pol_slum, on = 'country_c', how = 'inner')

# %%
ccefmlps['ccefmlps_pts'] = ccefmlps['ccefml_pts'] + ccefmlps['norm_with_pts_log5'] + ccefmlps['norm_log5']

# %%
ccefmlps = ccefmlps[['country_c', 'ccefmlps_pts']]

# %%
ccefmlps = ccefmlps.sort_values('ccefmlps_pts', ascending = False)

# %%
ccefmlps.to_csv('ccefmlps.csv', index=False, header=True)

# %% [markdown]
# # Something weird is going on when I try to read in the Sanitize CSV. Need to check this out later.
#
# san = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\Category_A\sanitize_withallpts_onlycountries.csv")

# %%
under = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\Category_A\undernourish_norm_with_pts_countryonly.csv")

# %%
regions_to_drop = [
    'Melanesia',
    'Polynesia'
]

under = under[~under['country'].isin(regions_to_drop)]

# %%
import country_converter as coco

under['country_c'] = coco.convert(names= under['country'], to='name_short', not_found =None)

# %%
ccefmlpsu = pd.merge(under,ccefmlps, on = 'country_c', how = 'inner')

# %%
import country_converter as coco

ccefmlps['country_c'] = coco.convert(names=ccefmlps['country_c'], to='name_short', not_found=None)

# %%
ccefmlps
# Out:
#                 country_c  ccefmlps_pts
# 35                 Kuwait    244.307711
# 16   United Arab Emirates    236.740303
# 30            South Korea    230.185262
# 0                   Italy    227.573026
# 18                 Israel    225.434466
# ..                    ...           ...
# 128              DR Congo     71.424128
# 138          Sierra Leone     67.860229
# 130               Somalia     63.062986
# 123                  Chad     40.441653
# 141           South Sudan     21.268265
#
# [142 rows x 2 columns]

# %%
water = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\Category_A\water_withallpts_onlycountries.csv")
water.columns
# Out:
# Index(['country', 'year', 'water_pct', 'norm_water', 'norm_water_withpts',
#        'norm_water_withpts_log5'],
#       dtype='object')

# %%
pip install thefuzz[speedup]
# Out:
# Requirement already satisfied: thefuzz[speedup] in c:\users\eabro\anaconda3\lib\site-packages (0.22.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in c:\users\eabro\anaconda3\lib\site-packages (from thefuzz[speedup]) (3.13.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install country_converter
# Out:
# Requirement already satisfied: country_converter in c:\users\eabro\anaconda3\lib\site-packages (1.3)
# Requirement already satisfied: pandas>=1.0 in c:\users\eabro\anaconda3\lib\site-packages (from country_converter) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\eabro\anaconda3\lib\site-packages (from pandas>=1.0->country_converter) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\eabro\anaconda3\lib\site-packages (from pandas>=1.0->country_converter) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\eabro\anaconda3\lib\site-packages (from pandas>=1.0->country_converter) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\eabro\anaconda3\lib\site-packages (from pandas>=1.0->country_converter) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\eabro\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0->country_converter) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import country_converter as coco

water['country'] = coco.convert(names=water['country'], to='name_short', not_found =None)
# Out:
#  Curaco not found in regex
#  Channel Islands not found in regex
#  Samoa not found in regex
#  Congo not found in regex

# %%
import country_converter as coco

# Manual fixes for countries not properly handled by coco
manual_fixes = {
    'Channel Islands': 'United Kingdom',
    'Samoa': 'Samoa',
    'Congo': 'Congo, Rep.',
}

# List of regional labels to exclude
regions_to_drop = [
    'Northern America',
    'Oceania',
    'Europe',
    'Americas',
    'Asia',
    'Africa'
]

# Clean function for standardizing country names
def clean_country_names(df, column='country', new_column='country_c', manual_fixes=None, drop_regions=None):
    df[column] = df[column].astype(str).str.strip()
    
    converted_names = []
    for name in df[column]:
        try:
            converted = coco.convert(names=name, to='name_short', not_found=None)
            converted_names.append(converted)
        except Exception:
            converted_names.append(None)
    
    df[new_column] = converted_names

    if manual_fixes:
        df[new_column] = df[new_column].fillna(df[column].map(manual_fixes))
    
    # Drop region-level labels if provided
    if drop_regions:
        df = df[~df[column].isin(drop_regions)]

    # Print any remaining unmatched names
    unmatched = df[df[new_column].isna()]
    if not unmatched.empty:
        print("❗ Unmatched country names:", unmatched[column].unique())

    return df

# ✅ Run on your `water` dataframe
water = clean_country_names(
    water,
    column='country',
    new_column='country_c',
    manual_fixes=manual_fixes,
    drop_regions=regions_to_drop
)
# Out:
# Curaco not found in regex
# Channel Islands not found in regex

# %%
#ccefmlps

# %%
water
# Out:
#                       country    year   water_pct  norm_water  \
# 0                   Gibraltar  2018.0  100.000000    1.000000
# 1                      Monaco  2018.0  100.000000    1.000000
# 2                   Singapore  2018.0  100.000000    1.000000
# 3               Liechtenstein  2018.0  100.000000    1.000000
# 4                  San Marino  2018.0  100.000000    1.000000
# ..                        ...     ...         ...         ...
# 220              Sierra Leone  2018.0   31.103751    0.030482
# 221                      Chad  2018.0   30.529295    0.022398
# 222  Central African Republic  2018.0   30.021749    0.015255
# 223                  Ethiopia  2018.0   29.815726    0.012356
# 224                  DR Congo  2018.0   28.937663    0.000000
#
#      norm_water_withpts  norm_water_withpts_log5                 country_c
# 0              5.000000                32.000000                 Gibraltar
# 1              5.000000                32.000000                    Monaco
# 2              5.000000                32.000000                 Singapore
# 3              5.000000                32.000000             Liechtenstein
# 4              5.000000                32.000000                San Marino
# ..                  ...                      ...                       ...
# 220            0.152408                 0.975409              Sierra Leone
# 221            0.111988                 0.716726                      Chad
# 222            0.076277                 0.488174  Central African Republic
# 223            0.061781                 0.395399                  Ethiopia
# 224            0.000000                 0.000000                  DR Congo
#
# [225 rows x 7 columns]

# %%
water

# %%
import country_converter as coco

# Step 1: Strip whitespace and ensure it's string
water['country'] = water['country'].astype(str).str.strip()

# Step 2: Safe conversion (no crash)
converted_names = []
for name in water['country']:
    try:
        converted = coco.convert(names=name, to='name_short', not_found=None)
        converted_names.append(converted)
    except Exception as e:
        print(f"Error converting {name}: {e}")
        converted_names.append(None)

# Step 3: Create cleaned column
water['country_c'] = converted_names

# Step 4: Show what didn't match
unmatched = water[water['country_c'].isna()]
print("❗ Unmatched country names:", unmatched['country'].unique())

# Step 5: Manual fixes (add to this as needed)
manual_fixes = {
    'Congo': 'Congo, Rep.',
    'Channel Islands': 'United Kingdom',
    'Samoa': 'Samoa'
}
water['country_c'] = water['country_c'].fillna(water['country'].map(manual_fixes))

# %%
uw = pd.merge(under, water, on = 'country_c', how = 'inner')

# %%
import country_converter as coco

def clean_country_names(pol, column='country', new_column='country_cleaned', manual_fixes=None):
    # Step 1: Basic cleanup
    pol['country'] = pol['country'].astype(str).str.strip()
    
    # Step 2: Try to convert names safely
    converted_names = []
    for name in pol['country']:
        try:
            converted = coco.convert(names=name, to='name_short', not_found=None)
            converted_names.append(converted)
        except Exception as e:
            print(f"Error converting {name}: {e}")
            converted_names.append(None)
    
    # Step 3: Assign new column
    pol['country_cleaned'] = converted_names
    
    # Step 4: Handle unmatched with manual fixes
    if manual_fixes is not None:
        pol['country_cleaned'] = pol['country_cleaned'].fillna(pol['country'].map(manual_fixes))
    
    # Step 5: Optional feedback
    unmatched = pol[pol['country_cleaned'].isna()]
    if not unmatched.empty:
        print("❗ Unmatched country names:", unmatched[column].unique())
    
    return df

# %%
water
# Out:
#                       country    year   water_pct  norm_water  \
# 0                   Gibraltar  2018.0  100.000000    1.000000
# 1                      Monaco  2018.0  100.000000    1.000000
# 2                   Singapore  2018.0  100.000000    1.000000
# 3               Liechtenstein  2018.0  100.000000    1.000000
# 4                  San Marino  2018.0  100.000000    1.000000
# ..                        ...     ...         ...         ...
# 220              Sierra Leone  2018.0   31.103751    0.030482
# 221                      Chad  2018.0   30.529295    0.022398
# 222  Central African Republic  2018.0   30.021749    0.015255
# 223                  Ethiopia  2018.0   29.815726    0.012356
# 224                  DR Congo  2018.0   28.937663    0.000000
#
#      norm_water_withpts  norm_water_withpts_log5                 country_c
# 0              5.000000                32.000000                 Gibraltar
# 1              5.000000                32.000000                    Monaco
# 2              5.000000                32.000000                 Singapore
# 3              5.000000                32.000000             Liechtenstein
# 4              5.000000                32.000000                San Marino
# ..                  ...                      ...                       ...
# 220            0.152408                 0.975409              Sierra Leone
# 221            0.111988                 0.716726                      Chad
# 222            0.076277                 0.488174  Central African Republic
# 223            0.061781                 0.395399                  Ethiopia
# 224            0.000000                 0.000000                  DR Congo
#
# [225 rows x 7 columns]

# %%
import country_converter as coco

# Manual fixes (expand this as needed)
manual_fixes = {
    'Congo': 'Congo, Rep.',
    'Channel Islands': 'United Kingdom',
    'Samoa': 'Samoa',
    'Ivory Coast': "Côte d'Ivoire",
    'Syria': 'Syrian Arab Republic',
    'Palestine': 'Palestine, State of',
    # Add more as needed!
}

def clean_country_names(df, column='country', new_column='country_cleaned', manual_fixes=None):
    df[column] = df[column].astype(str).str.strip()
    
    converted_names = []
    for name in df[column]:
        try:
            converted = coco.convert(names=name, to='name_short', not_found=None)
            converted_names.append(converted)
        except Exception as e:
            print(f"Error converting {name}: {e}")
            converted_names.append(None)
    
    df[new_column] = converted_names

    if manual_fixes is not None:
        df[new_column] = df[new_column].fillna(df[column].map(manual_fixes))
    
    unmatched = df[df[new_column].isna()]
    if not unmatched.empty:
        print("❗ Unmatched country names in `pol`:", unmatched[column].unique())
    
    return df

# ✅ Clean the `pol` dataframe
pol = clean_country_names(pol, manual_fixes=manual_fixes)

# %%
pol
# Out:
#          country    year   pm_value  norm_pm_value  norm_with_pts  \
# 0        Bahamas  2014.5   5.305895       0.000000       5.000000
# 1        Finland  2014.5   6.002784       0.011293       4.943533
# 2        Iceland  2014.5   6.296681       0.016056       4.919719
# 3         Sweden  2014.5   6.532031       0.019870       4.900649
# 4           Niue  2014.5   6.553944       0.020225       4.898873
# ..           ...     ...        ...            ...            ...
# 190        Egypt  2014.5  61.554086       0.911535       0.442326
# 191        Qatar  2014.5  62.362459       0.924635       0.376826
# 192   Tajikistan  2014.5  63.495392       0.942995       0.285026
# 193       Kuwait  2014.5  65.130785       0.969497       0.152514
# 194  Afghanistan  2014.5  67.013023       1.000000       0.000000
#
#      norm_with_pts_log5    country_c country_cleaned
# 0              0.000000      Bahamas         Bahamas
# 1              0.361392      Finland         Finland
# 2              0.513800      Iceland         Iceland
# 3              0.635848       Sweden          Sweden
# 4              0.647212         Niue            Niue
# ..                  ...          ...             ...
# 190           29.169112        Egypt           Egypt
# 191           29.588317        Qatar           Qatar
# 192           30.175832   Tajikistan      Tajikistan
# 193           31.023912       Kuwait          Kuwait
# 194           32.000000  Afghanistan     Afghanistan
#
# [195 rows x 8 columns]

# %%
pol_water = pd.merge(pol, water, on = 'country_c', how = 'inner')

# %%
pol_water
# Out:
#         country_x  year_x   pm_value  norm_pm_value  norm_with_pts  \
# 0         Bahamas  2014.5   5.305895       0.000000       5.000000
# 1         Finland  2014.5   6.002784       0.011293       4.943533
# 2         Iceland  2014.5   6.296681       0.016056       4.919719
# 3          Sweden  2014.5   6.532031       0.019870       4.900649
# 4            Niue  2014.5   6.553944       0.020225       4.898873
# ..            ...     ...        ...            ...            ...
# 186  Saudi Arabia  2014.5  57.001537       0.837758       0.811210
# 187         Egypt  2014.5  61.554086       0.911535       0.442326
# 188         Qatar  2014.5  62.362459       0.924635       0.376826
# 189    Tajikistan  2014.5  63.495392       0.942995       0.285026
# 190        Kuwait  2014.5  65.130785       0.969497       0.152514
#
#      norm_with_pts_log5     country_c country_cleaned     country_y  \
# 0              0.000000       Bahamas         Bahamas       Bahamas
# 1              0.361392       Finland         Finland       Finland
# 2              0.513800       Iceland         Iceland       Iceland
# 3              0.635848        Sweden          Sweden        Sweden
# 4              0.647212          Niue            Niue          Niue
# ..                  ...           ...             ...           ...
# 186           26.808257  Saudi Arabia    Saudi Arabia  Saudi Arabia
# 187           29.169112         Egypt           Egypt         Egypt
# 188           29.588317         Qatar           Qatar         Qatar
# 189           30.175832    Tajikistan      Tajikistan    Tajikistan
# 190           31.023912        Kuwait          Kuwait        Kuwait
#
#         year_y   water_pct  norm_water  norm_water_withpts  \
# 0    2016.5000   98.879833    0.984237            4.921184
# 1    2018.0000   99.803081    0.997229            4.986145
# 2    2018.0000   99.644100    0.994992            4.974959
# 3    2018.0000   99.694980    0.995708            4.978539
# 4    2018.0000   95.770680    0.940484            4.702422
# ..         ...         ...         ...                 ...
# 186  2018.5000   99.328363    0.990549            4.952743
# 187  2017.5625   94.703870    0.925472            4.627360
# 188  2018.0000   98.433561    0.977957            4.889784
# 189  2018.0000   69.629541    0.572622            2.863111
# 190  2018.0000  100.000000    1.000000            5.000000
#
#      norm_water_withpts_log5
# 0                  31.495579
# 1                  31.911326
# 2                  31.839735
# 3                  31.862647
# 4                  30.095500
# ..                       ...
# 186                31.697556
# 187                29.615106
# 188                31.294619
# 189                18.323913
# 190                32.000000
#
# [191 rows x 14 columns]

# %%
# ccefmlps

import country_converter as coco

under['country_c'] = coco.convert(names=under['country'], to='name_short', not_found=None)

# %%
regions_to_drop = ['Melanesia', 'Polynesia']
under = under[~under['country'].isin(regions_to_drop)]

# %%
under['under_pts_log32'] = under['norm_undernourish'] * 32

# %%
uw = pd.merge(under, water, on = 'country_c', how = 'inner')

# %%
ccefmlpsuw = pd.merge(ccefmlps, uw, on = 'country_c', how = 'inner')
ccefmlpsuw['ccefmlpsuw_pts'] = ccefmlpsuw['under_pts_log32'] + ccefmlpsuw['norm_water_withpts_log5'] + ccefmlpsuw['ccefmlps_pts']

# %%
san = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\Category_A\sanitize_withallpts_onlycountries.csv")

# %%
import country_converter as coco

# Manual fixes for countries not properly handled by coco
manual_fixes = {
    'Channel Islands': 'United Kingdom',
    'Samoa': 'Samoa',
    'Congo': 'Congo, Rep.',
}

# List of region-level entries to remove
regions_to_drop = [
    'Northern America',
    'Oceania',
    'Europe',
    'Americas',
    'Asia',
    'Africa'
]

# Clean function to standardize country names
def clean_country_names(df, column='country', new_column='country_c', manual_fixes=None, drop_regions=None):
    df[column] = df[column].astype(str).str.strip()
    
    converted_names = []
    for name in df[column]:
        try:
            converted = coco.convert(names=name, to='name_short', not_found=None)
            converted_names.append(converted)
        except Exception:
            converted_names.append(None)
    
    df[new_column] = converted_names

    if manual_fixes:
        df[new_column] = df[new_column].fillna(df[column].map(manual_fixes))
    
    if drop_regions:
        df = df[~df[column].isin(drop_regions)]

    unmatched = df[df[new_column].isna()]
    if not unmatched.empty:
        print("❗ Unmatched country names:", unmatched[column].unique())

    return df

# ✅ Apply to the `san` dataframe
san = clean_country_names(
    san,
    column='country',
    new_column='country_c',
    manual_fixes=manual_fixes,
    drop_regions=regions_to_drop
)
# Out:
# Channel Islands not found in regex

# %%
ccefmlpsuw
# Out:
#                 country_c  ccefmlps_pts                     country_x  year_x  \
# 0                  Kuwait    244.307711                        Kuwait  2017.5
# 1    United Arab Emirates    236.740303          United Arab Emirates  2017.5
# 2             South Korea    230.185262                   South Korea  2017.5
# 3                   Italy    227.573026                         Italy  2017.5
# 4                  Israel    225.434466                        Israel  2017.5
# ..                    ...           ...                           ...     ...
# 127              DR Congo     71.424128  Democratic Republic of Congo  2017.5
# 128          Sierra Leone     67.860229                  Sierra Leone  2017.5
# 129               Somalia     63.062986                       Somalia  2017.5
# 130                  Chad     40.441653                          Chad  2017.5
# 131           South Sudan     21.268265                   South Sudan  2021.0
#
#      pct_undernourish  norm_undernourish  norm_with_pts  under_pts_log32  \
# 0                2.50           1.000000       5.000000        32.000000
# 1                3.84           0.975098       4.875488        31.203122
# 2                2.50           1.000000       5.000000        32.000000
# 3                2.50           1.000000       5.000000        32.000000
# 4                2.50           1.000000       5.000000        32.000000
# ..                ...                ...            ...              ...
# 127             33.13           0.430775       2.153875        13.784798
# 128             26.33           0.557146       2.785728        17.828656
# 129             56.31           0.000000       0.000000         0.000000
# 130             28.55           0.515889       2.579446        16.508456
# 131             19.50           0.684074       3.420368        21.890355
#
#                 country_y       year_y   water_pct  norm_water  \
# 0                  Kuwait  2018.000000  100.000000    1.000000
# 1    United Arab Emirates  2018.000000   99.973241    0.999623
# 2             South Korea  2018.000000   99.289160    0.989997
# 3                   Italy  2018.000000   96.713262    0.953749
# 4                  Israel  2018.000000   99.764349    0.996684
# ..                    ...          ...         ...         ...
# 127              DR Congo  2018.000000   28.937663    0.000000
# 128          Sierra Leone  2018.000000   31.103751    0.030482
# 129               Somalia  2018.000000   51.950023    0.323833
# 130                  Chad  2018.000000   30.529295    0.022398
# 131           South Sudan  2018.235294   42.712079    0.193836
#
#      norm_water_withpts  norm_water_withpts_log5  ccefmlpsuw_pts
# 0              5.000000                32.000000      308.307711
# 1              4.998117                31.987950      299.931376
# 2              4.949985                31.679903      293.865165
# 3              4.768743                30.519953      290.092979
# 4              4.983419                31.893884      289.328350
# ..                  ...                      ...             ...
# 127            0.000000                 0.000000       85.208926
# 128            0.152408                 0.975409       86.664294
# 129            1.619167                10.362670       73.425656
# 130            0.111988                 0.716726       57.666834
# 131            0.969178                 6.202742       49.361362
#
# [132 rows x 15 columns]

# %%
ccefmlpssuw = pd.merge(ccefmlpsuw, san, on = 'country_c', how = 'inner')
ccefmlpssuw
# Out:
#                 country_c  ccefmlps_pts                     country_x  year_x  \
# 0                  Kuwait    244.307711                        Kuwait  2017.5
# 1    United Arab Emirates    236.740303          United Arab Emirates  2017.5
# 2             South Korea    230.185262                   South Korea  2017.5
# 3                   Italy    227.573026                         Italy  2017.5
# 4                  Israel    225.434466                        Israel  2017.5
# ..                    ...           ...                           ...     ...
# 127              DR Congo     71.424128  Democratic Republic of Congo  2017.5
# 128          Sierra Leone     67.860229                  Sierra Leone  2017.5
# 129               Somalia     63.062986                       Somalia  2017.5
# 130                  Chad     40.441653                          Chad  2017.5
# 131           South Sudan     21.268265                   South Sudan  2021.0
#
#      pct_undernourish  norm_undernourish  norm_with_pts  under_pts_log32  \
# 0                2.50           1.000000       5.000000        32.000000
# 1                3.84           0.975098       4.875488        31.203122
# 2                2.50           1.000000       5.000000        32.000000
# 3                2.50           1.000000       5.000000        32.000000
# 4                2.50           1.000000       5.000000        32.000000
# ..                ...                ...            ...              ...
# 127             33.13           0.430775       2.153875        13.784798
# 128             26.33           0.557146       2.785728        17.828656
# 129             56.31           0.000000       0.000000         0.000000
# 130             28.55           0.515889       2.579446        16.508456
# 131             19.50           0.684074       3.420368        21.890355
#
#                 country_y       year_y  ...  norm_water  norm_water_withpts  \
# 0                  Kuwait  2018.000000  ...    1.000000            5.000000
# 1    United Arab Emirates  2018.000000  ...    0.999623            4.998117
# 2             South Korea  2018.000000  ...    0.989997            4.949985
# 3                   Italy  2018.000000  ...    0.953749            4.768743
# 4                  Israel  2018.000000  ...    0.996684            4.983419
# ..                    ...          ...  ...         ...                 ...
# 127              DR Congo  2018.000000  ...    0.000000            0.000000
# 128          Sierra Leone  2018.000000  ...    0.030482            0.152408
# 129               Somalia  2018.000000  ...    0.323833            1.619167
# 130                  Chad  2018.000000  ...    0.022398            0.111988
# 131           South Sudan  2018.235294  ...    0.193836            0.969178
#
#      norm_water_withpts_log5  ccefmlpsuw_pts  \
# 0                  32.000000      308.307711
# 1                  31.987950      299.931376
# 2                  31.679903      293.865165
# 3                  30.519953      290.092979
# 4                  31.893884      289.328350
# ..                       ...             ...
# 127                 0.000000       85.208926
# 128                 0.975409       86.664294
# 129                10.362670       73.425656
# 130                 0.716726       57.666834
# 131                 6.202742       49.361362
#
#                               country    year  sanitation_value  \
# 0                              Kuwait  2018.0        100.000000
# 1                United Arab Emirates  2018.0         99.793913
# 2                   Republic of Korea  2018.0         99.866420
# 3                               Italy  2018.0         99.985911
# 4                              Israel  2018.0         99.948734
# ..                                ...     ...               ...
# 127  Democratic Republic of the Congo  2018.0         35.353409
# 128                      Sierra Leone  2018.0         52.621150
# 129                           Somalia  2018.0         54.008085
# 130                              Chad  2018.0         17.432141
# 131                       South Sudan  2018.0         22.086124
#
#      norm_sanitize  norm_sanitize_withpts5  norm_sanitize_withpts_log5
# 0         1.000000                5.000000                   32.000000
# 1         0.997551                4.987753                   31.921618
# 2         0.998412                4.992062                   31.949195
# 3         0.999833                4.999163                   31.994641
# 4         0.999391                4.996953                   31.980502
# ..             ...                     ...                         ...
# 127       0.231647                1.158234                    7.412698
# 128       0.436882                2.184408                   13.980208
# 129       0.453366                2.266829                   14.507707
# 130       0.018645                0.093223                    0.596629
# 131       0.073959                0.369796                    2.366697
#
# [132 rows x 21 columns]

# %%
ccefmlpssuw['ccefmlpssuw_pts'] = ccefmlpssuw['norm_sanitize_withpts_log5'] + ccefmlpssuw['ccefmlps_pts']

# %%
ccefmlpssuw_points = ccefmlpssuw[['country_c', 'ccefmlpssuw_pts']]
cat_aa = ccefmlpssuw_points

# %%
road = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\Category_A\road_withpts_onlycountries.csv")

# %%
road['country_c'] = coco.convert(names= road['country'], to='name_short', not_found=None)

# %%
cat_a = pd.merge(cat_a, road, on = 'country_c', how = 'inner' )

# %%
cat_a['ccefmlpssuwt'] = cat_a
# Out:
#                 country_c  ccefmlpssuw_pts                       country  \
# 0                  Kuwait       276.307711                        Kuwait
# 1    United Arab Emirates       268.661922          United Arab Emirates
# 2             South Korea       262.134457                   South Korea
# 3                   Italy       259.567668                         Italy
# 4                  Israel       257.414968                        Israel
# ..                    ...              ...                           ...
# 127              DR Congo        78.836825  Democratic Republic of Congo
# 128          Sierra Leone        81.840437                  Sierra Leone
# 129               Somalia        77.570693                       Somalia
# 130                  Chad        41.038281                          Chad
# 131           South Sudan        23.634962                   South Sudan
#
#             year  death_traffic  norm_traffic  traffic_pts
# 0    2014.666667      18.100000      0.585326    18.730420
# 1    2014.666667      15.466667      0.650453    20.814509
# 2    2014.666667      10.966667      0.761748    24.375927
# 3    2014.666667       6.166667      0.880462    28.174773
# 4    2014.666667       4.333333      0.925804    29.625721
# ..           ...            ...           ...          ...
# 127  2014.666667      34.800000      0.172300     5.513603
# 128  2014.666667      31.133333      0.262984     8.415499
# 129  2014.666667      27.433333      0.354493    11.343776
# 130  2014.666667      27.600000      0.350371    11.211871
# 131  2014.666667      31.700000      0.248969     7.967024
#
# [132 rows x 7 columns]

# %%
ccefmlpssuw_points.to_csv('Points_Category_A_Complete0413.csv', index=False, header=True)

# %%
cat_b = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\All_Categories_Points\Points_Category_B_Complete0412.csv")

# %%
cat_a_b = pd.merge(cat_a, cat_b, on = 'country_c', how = 'inner')
cat_a_b
# Out:
#                country_c  ccefmlpssuw_pts               country    all7pts
# 0                 Kuwait       276.307711                Kuwait  80.749510
# 1   United Arab Emirates       268.661922  United Arab Emirates  78.757195
# 2            South Korea       262.134457           South Korea  84.819722
# 3                  Italy       259.567668                 Italy  81.702278
# 4                 Israel       257.414968                Israel  78.594187
# ..                   ...              ...                   ...        ...
# 88              Tanzania       107.754518              Tanzania  66.587901
# 89                Uganda       103.499358                Uganda  64.979462
# 90                 Haiti        99.887952                 Haiti  52.333273
# 91                Malawi        94.629250                Malawi  70.194156
# 92          Sierra Leone        81.840437          Sierra Leone  76.960886
#
# [93 rows x 4 columns]

# %%
cat_a_b['a_b_pts'] = cat_a_b['ccefmlpssuw_pts'] +cat_a_b['all7pts']

# %%
# ccefmlps

import country_converter as coco

cat_b['country_c'] = coco.convert(names=cat_b['country'], to='name_short', not_found=None)

# %%
cat_a_b = cat_a_b.sort_values('a_b_pts', ascending = False)

# %%
catab
# Out:
#      norm_crime_rate_log16     country_c  norm_gini_log16  \
# 0                13.095168   Switzerland        13.132946
# 1                11.385066        Norway        13.055823
# 2                12.860908   Netherlands        13.756746
# 3                12.743777       Czechia        16.000000
# 4                12.158126       Austria        12.339092
# ..                     ...           ...              ...
# 98                3.513909       Nigeria         8.377970
# 99                2.951684         Yemen         2.157319
# 100               2.951684         Yemen         2.157319
# 101               2.951684         Yemen         2.157319
# 102               1.358712  South Africa         0.000000
#
#      homicide_norm_withpts_log16  norm_vac_withpts_log16   ihvg_pts  \
# 0                      15.850197               13.783205  53.667652
# 1                      15.818452               15.281173  56.504032
# 2                      15.812411               14.411263  53.170516
# 3                      15.792009               15.305563  53.318915
# 4                      15.812785               14.072937  51.102780
# ..                           ...                     ...        ...
# 98                      9.044233                     NaN        NaN
# 99                     14.671193                4.022372        NaN
# 100                    14.671193                4.022372        NaN
# 101                    14.671193                4.022372        NaN
# 102                     7.678772                     NaN        NaN
#
#      healthgdp_norm_withpts_log5  gini_log16  terror_log16  ineq_terror  \
# 0                       9.012299   13.132946     15.990344    29.123290
# 1                       7.954588   13.055823     15.993315    29.049139
# 2                       8.645222   13.756746     15.950979    29.707726
# 3                       5.899716   16.000000     15.988116    31.988116
# 4                       8.741722   12.339092     15.991830    28.330922
# ..                           ...         ...           ...          ...
# 98                      1.329234    8.377970     11.842912    20.220882
# 99                      2.736424    2.157319     16.000000    18.157319
# 100                     2.736424    2.157319     16.000000    18.157319
# 101                     2.736424    2.157319     11.541361    13.698680
# 102                     6.175024    0.000000     15.855909    15.855909
#
#      ihhuvgtc_pts  ccefmlpssuw_pts
# 0      104.898410       256.147570
# 1      104.892825       253.184199
# 2      104.384372       255.104394
# 3      103.950525       255.410652
# 4      100.333550       255.737532
# ..            ...              ...
# 98            NaN       101.796284
# 99            NaN       170.174354
# 100           NaN       170.174354
# 101           NaN       170.174354
# 102           NaN       204.244592
#
# [103 rows x 12 columns]

# %%
(7*16) + (11*32)
# Out:
# 464

# %%
# 4/13
cat_a = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\All_Categories_Points\Points_Category_A_Complete0413.csv")

# %%
ccefmlpssuw
# Out:
#                 country_c  ccefmlps_pts                     country_x  year_x  \
# 0                  Kuwait    244.307711                        Kuwait  2017.5
# 1    United Arab Emirates    236.740303          United Arab Emirates  2017.5
# 2             South Korea    230.185262                   South Korea  2017.5
# 3                   Italy    227.573026                         Italy  2017.5
# 4                  Israel    225.434466                        Israel  2017.5
# ..                    ...           ...                           ...     ...
# 127              DR Congo     71.424128  Democratic Republic of Congo  2017.5
# 128          Sierra Leone     67.860229                  Sierra Leone  2017.5
# 129               Somalia     63.062986                       Somalia  2017.5
# 130                  Chad     40.441653                          Chad  2017.5
# 131           South Sudan     21.268265                   South Sudan  2021.0
#
#      pct_undernourish  norm_undernourish  norm_with_pts  under_pts_log32  \
# 0                2.50           1.000000       5.000000        32.000000
# 1                3.84           0.975098       4.875488        31.203122
# 2                2.50           1.000000       5.000000        32.000000
# 3                2.50           1.000000       5.000000        32.000000
# 4                2.50           1.000000       5.000000        32.000000
# ..                ...                ...            ...              ...
# 127             33.13           0.430775       2.153875        13.784798
# 128             26.33           0.557146       2.785728        17.828656
# 129             56.31           0.000000       0.000000         0.000000
# 130             28.55           0.515889       2.579446        16.508456
# 131             19.50           0.684074       3.420368        21.890355
#
#                 country_y       year_y  ...  norm_water_withpts  \
# 0                  Kuwait  2018.000000  ...            5.000000
# 1    United Arab Emirates  2018.000000  ...            4.998117
# 2             South Korea  2018.000000  ...            4.949985
# 3                   Italy  2018.000000  ...            4.768743
# 4                  Israel  2018.000000  ...            4.983419
# ..                    ...          ...  ...                 ...
# 127              DR Congo  2018.000000  ...            0.000000
# 128          Sierra Leone  2018.000000  ...            0.152408
# 129               Somalia  2018.000000  ...            1.619167
# 130                  Chad  2018.000000  ...            0.111988
# 131           South Sudan  2018.235294  ...            0.969178
#
#      norm_water_withpts_log5  ccefmlpsuw_pts  \
# 0                  32.000000      308.307711
# 1                  31.987950      299.931376
# 2                  31.679903      293.865165
# 3                  30.519953      290.092979
# 4                  31.893884      289.328350
# ..                       ...             ...
# 127                 0.000000       85.208926
# 128                 0.975409       86.664294
# 129                10.362670       73.425656
# 130                 0.716726       57.666834
# 131                 6.202742       49.361362
#
#                               country    year sanitation_value  norm_sanitize  \
# 0                              Kuwait  2018.0       100.000000       1.000000
# 1                United Arab Emirates  2018.0        99.793913       0.997551
# 2                   Republic of Korea  2018.0        99.866420       0.998412
# 3                               Italy  2018.0        99.985911       0.999833
# 4                              Israel  2018.0        99.948734       0.999391
# ..                                ...     ...              ...            ...
# 127  Democratic Republic of the Congo  2018.0        35.353409       0.231647
# 128                      Sierra Leone  2018.0        52.621150       0.436882
# 129                           Somalia  2018.0        54.008085       0.453366
# 130                              Chad  2018.0        17.432141       0.018645
# 131                       South Sudan  2018.0        22.086124       0.073959
#
#      norm_sanitize_withpts5  norm_sanitize_withpts_log5  ccefmlpssuw_pts
# 0                  5.000000                   32.000000       276.307711
# 1                  4.987753                   31.921618       268.661922
# 2                  4.992062                   31.949195       262.134457
# 3                  4.999163                   31.994641       259.567668
# 4                  4.996953                   31.980502       257.414968
# ..                      ...                         ...              ...
# 127                1.158234                    7.412698        78.836825
# 128                2.184408                   13.980208        81.840437
# 129                2.266829                   14.507707        77.570693
# 130                0.093223                    0.596629        41.038281
# 131                0.369796                    2.366697        23.634962
#
# [132 rows x 22 columns]

# %%
catb = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\All_Categories_Points\Points_Category_B_Method2.csv")

# %%
cat_a
# Out:
#                 country_c  ccefmlpssuw_pts
# 0                  Kuwait       276.307711
# 1    United Arab Emirates       268.661922
# 2             South Korea       262.134457
# 3                   Italy       259.567668
# 4                  Israel       257.414968
# ..                    ...              ...
# 127              DR Congo        78.836825
# 128          Sierra Leone        81.840437
# 129               Somalia        77.570693
# 130                  Chad        41.038281
# 131           South Sudan        23.634962
#
# [132 rows x 2 columns]

# %%
cat_a.columns
# Out:
# Index(['country_c', 'ccefmlpssuw_pts', 'country', 'year', 'death_traffic',
#        'norm_traffic'],
#       dtype='object')

# %%
cat_a = cat_a.sort_values('ccefmlpssuw_pts', ascending = False)

# %%
cat_a.head(25)
# Out:
#                country_c  ccefmlpssuw_pts               country         year  \
# 0                 Kuwait       276.307711                Kuwait  2014.666667
# 1   United Arab Emirates       268.661922  United Arab Emirates  2014.666667
# 2            South Korea       262.134457           South Korea  2014.666667
# 3                  Italy       259.567668                 Italy  2014.666667
# 4                 Israel       257.414968                Israel  2014.666667
# 5                  Japan       257.099960                 Japan  2014.666667
# 6                  Egypt       256.344186                 Egypt  2014.666667
# 7            Switzerland       256.147570           Switzerland  2014.666667
# 8                  Malta       255.800562                 Malta  2014.666667
# 9                Austria       255.737532               Austria  2014.666667
# 10                Poland       255.457931                Poland  2014.666667
# 11               Czechia       255.410652               Czechia  2014.666667
# 12              Slovenia       255.125807              Slovenia  2014.666667
# 13           Netherlands       255.104394           Netherlands  2014.666667
# 14               Belgium       255.101205               Belgium  2014.666667
# 15               Germany       255.099069               Germany  2014.666667
# 16                France       254.913027                France  2014.666667
# 17            Luxembourg       254.784838            Luxembourg  2014.666667
# 19                Greece       254.256272                Greece  2014.666667
# 20                 Spain       254.211449                 Spain  2014.666667
# 21              Slovakia       253.758446              Slovakia  2014.666667
# 22        United Kingdom       253.492941        United Kingdom  2014.666667
# 23               Denmark       253.390996               Denmark  2014.666667
# 24                Norway       253.184199                Norway  2014.666667
# 25                Sweden       252.537848                Sweden  2014.666667
#
#     death_traffic  norm_traffic
# 0       18.100000      0.585326
# 1       15.466667      0.650453
# 2       10.966667      0.761748
# 3        6.166667      0.880462
# 4        4.333333      0.925804
# 5        4.366667      0.924979
# 6       11.833333      0.740313
# 7        3.200000      0.953833
# 8        3.600000      0.943941
# 9        5.800000      0.889530
# 10      10.233333      0.779885
# 11       6.966667      0.860676
# 12       6.100000      0.882110
# 13       3.933333      0.935697
# 14       6.866667      0.863149
# 15       4.333333      0.925804
# 16       5.700000      0.892003
# 17       5.700000      0.892003
# 19      10.233333      0.779885
# 20       4.500000      0.921682
# 21       7.166667      0.855730
# 22       3.266667      0.952185
# 23       4.066667      0.932399
# 24       3.033333      0.957955
# 25       3.100000      0.956307

# %%
# April 16th: Cleaned up final 5 datasets for category A. Joining them together now and determining next steps for missing countries.

# %%
polu = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\Category_A\Pollution_20152019.csv")
basics= pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\Category_A\Basic_san20172022.csv")
water = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\Category_A\Basicwater_20162022.csv")
calorie = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\Category_A\Calorie_20192023.csv")
life = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\Category_A\LifeExpect_2018.csv")

# %%
polu.shape, basics.shape, water.shape, calorie.shape, life.shape
# Out:
# ((195, 5), (228, 11), (231, 6), (145, 5), (237, 10))

# %%
polu['country_c'] = coco.convert(names= polu['country'], to='name_short', not_found=None)
calorie['country_c'] = coco.convert(names= calorie['country'], to='name_short', not_found=None)

# %%
ps = pd.merge(polu, basics, on = 'country_c', how = 'inner')
ps_o = pd.merge(polu, basics, on = 'country_c', how = 'outer')

# %%
psw = pd.merge(ps, water, on = 'country_c', how = 'inner')
psw_o = pd.merge(ps, water, on = 'country_c', how = 'outer')

# %%
psw  = psw[['country_c', 'pm25', 'norm_pol2', 'pol_log32_n', 'safe',  'atleast_basicsan', 'norm_basicsan',
       'basicsan_log32_n', 'basicw', 'norm_water',
       'water_log32_n']]

# %%
pswc = pd.merge(psw, calorie, on = 'country_c', how = 'inner')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[1110], line 1
# ----> 1 pswc = pd.merge(psw, calorie, on = 'country_c', how = 'inner')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:888, in _MergeOperation.get_result(self, copy)
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     886 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#     893 if self.indicator:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:840, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     837 left = self.left[:]
#     838 right = self.right[:]
# --> 840 llabels, rlabels = _items_overlap_with_suffix(
#     841     self.left._info_axis, self.right._info_axis, self.suffixes
#     842 )
#     844 if left_indexer is not None and not is_range_indexer(left_indexer, len(left)):
#     845     # Pinning the index here (and in the right code just below) is not
#     846     #  necessary, but makes the `.take` more performant if we have e.g.
#     847     #  a MultiIndex for left.index.
#     848     lmgr = left._mgr.reindex_indexer(
#     849         join_index,
#     850         left_indexer,
#    (...)
#     855         use_na_proxy=True,
#     856     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:2757, in _items_overlap_with_suffix(left, right, suffixes)
#    2755     dups.extend(rlabels[(rlabels.duplicated()) & (~right.duplicated())].tolist())
#    2756 if dups:
# -> 2757     raise MergeError(
#    2758         f"Passing 'suffixes' which cause duplicate columns {set(dups)} is "
#    2759         f"not allowed.",
#    2760     )
#    2762 return llabels, rlabels
#
# MergeError: Passing 'suffixes' which cause duplicate columns {'year_x', 'country_x'} is not allowed.

# %%
pswcl = pd.merge(pswc, life, on = 'country_c', how = 'inner')
pswcl_o = pd.merge(pswc, life, on = 'country_c', how = 'outer')

# %%
pswcl = pswcl[['country_c', 'pm25', 'norm_pol2', 'pol_log32_n', 'safe',  'atleast_basicsan', 'norm_basicsan',
       'basicsan_log32_n', 'basicw', 'norm_water',
       'water_log32_n', 'calorie',
       'norm_calorie', 'calorie_log32_n', 'avg_life', 'norm_life_expect', 'norm_pts_log5', 'lifeexpect_log32_n']]

# %%
pswcl = pswcl.drop('norm_pts_log5', axis = 1)
pswcl_o = pswcl.drop('norm_pts_log5', axis = 1)

# %%
pswcl['category_a_pts'] = pswcl['pol_log32_n'] + pswcl['basicsan_log32_n'] + pswcl['water_log32_n'] + pswcl['calorie_log32_n'] + pswcl['lifeexpect_log32_n']

# %%
pswcl_o['category_a_pts'] = pswcl_o['pol_log32_n'] + pswcl_o['basicsan_log32_n'] + pswcl_o['water_log32_n'] + pswcl_o['calorie_log32_n'] + pswcl_o['lifeexpect_log32_n']

# %%
pswcl = pswcl.sort_values('category_a_pts', ascending = False).reset_index()

# %%
pswcl.to_csv('Points_Category_A_Inner_Complete0416.csv', index=False, header=True)

# %%
pswcl_o = pswcl_o.sort_values('category_a_pts', ascending = False).reset_index()

# %%
pswcl_o.to_csv('Points_Category_A_Outer_Complete0416.csv', index=False, header=True)
# Out:
#       country_c       pm25  norm_pol2  pol_log32_n       safe  \
# 0       Finland   5.525910   0.999542    31.985359  89.609373
# 1       Iceland   5.909562   0.993123    31.779924   0.000000
# 2        Sweden   6.046158   0.990837    31.706780  95.502112
# 3       Estonia   6.378954   0.985268    31.528577  90.421816
# 4        Norway   6.428530   0.984438    31.502030  77.876965
# ..          ...        ...        ...          ...        ...
# 138    Pakistan  53.631344   0.194568     6.226183   0.000000
# 139     Nigeria  56.813564   0.141318     4.522189  30.311561
# 140    Cameroon  58.351032   0.115591     3.698916   0.000000
# 141  Tajikistan  59.523014   0.095980     3.071351   0.000000
# 142       Egypt  62.186678   0.051407     1.645030  66.292627
#
#      atleast_basicsan  norm_basicsan  basicsan_log32_n      basicw  \
# 0           99.999956       1.000000         31.999985  100.000000
# 1            1.219210       0.012192          0.390147  100.000000
# 2           99.589598       0.995896         31.868670   99.715433
# 3           99.770448       0.997704         31.926543   99.972120
# 4          100.000002       1.000000         32.000000   99.999999
# ..                ...            ...               ...         ...
# 138         10.128144       0.101281          3.241006   90.187921
# 139         61.586757       0.615868         19.707762   74.725992
# 140         17.119519       0.171195          5.478246   67.998398
# 141          2.623740       0.026237          0.839597   80.649989
# 142         99.047573       0.990476         31.695223   98.756091
#
#      norm_water  ...  norm_calorie calorie_log32_n   country_y  year_y  \
# 0      1.000000  ...      0.994924       31.837563     Finland    2018
# 1      1.000000  ...      0.994924       31.837563     Iceland    2018
# 2      0.995577  ...      0.965736       30.903553      Sweden    2018
# 3      0.999567  ...      0.958122       30.659898     Estonia    2018
# 4      1.000000  ...      0.984772       31.512690      Norway    2018
# ..          ...  ...           ...             ...         ...     ...
# 138    0.847496  ...      0.875635       28.020305    Pakistan    2018
# 139    0.607179  ...      0.229695        7.350254     Nigeria    2018
# 140    0.502615  ...      0.601523       19.248731    Cameroon    2018
# 141    0.699252  ...      0.906091       28.994924  Tajikistan    2018
# 142    0.980667  ...      0.920051       29.441624       Egypt    2018
#
#      avg_life  median_life avg_med_life  norm_life_expect  norm_with_pts  \
# 0       81.49        81.50        81.49          0.898182       4.490909
# 1       82.32        82.43        82.38          0.918303       4.591515
# 2       82.59        82.44        82.51          0.924848       4.624242
# 3       78.06        78.17        78.12          0.815030       4.075152
# 4       82.64        82.63        82.64          0.926061       4.630303
# ..        ...          ...          ...               ...            ...
# 138     66.19        65.94        66.07          0.527273       2.636364
# 139     52.82        52.67        52.75          0.203152       1.015758
# 140     60.95        61.15        61.05          0.400242       2.001212
# 141     70.25        69.98        70.11          0.625697       3.128485
# 142     70.40        70.44        70.42          0.629333       3.146667
#
#      lifeexpect_log32_n
# 0             28.741818
# 1             29.385697
# 2             29.595152
# 3             26.080970
# 4             29.633939
# ..                  ...
# 138           16.872727
# 139            6.500848
# 140           12.807758
# 141           20.022303
# 142           20.138667
#
# [143 rows x 24 columns]

# %%
pswcl_o
# Out:
#      index                  country_c      pm25  norm_pol2  pol_log32_n  \
# 0      157                     Norway  6.428530   0.984438    31.502030
# 1       70                    Finland  5.525910   0.999542    31.985359
# 2       11                  Australia  7.241084   0.970842    31.066929
# 3      203                     Sweden  6.046158   0.990837    31.706780
# 4      204                Switzerland  9.935088   0.925761    29.624362
# ..     ...                        ...       ...        ...          ...
# 232    230                  Venezuela       NaN        NaN          NaN
# 233    232  Wallis and Futuna Islands       NaN        NaN          NaN
# 234    233             Western Sahara       NaN        NaN          NaN
# 235    234                      Yemen       NaN        NaN          NaN
# 236    236                   Zimbabwe       NaN        NaN          NaN
#
#           safe  atleast_basicsan  norm_basicsan  basicsan_log32_n      basicw  \
# 0    77.876965        100.000002       1.000000         32.000000   99.999999
# 1    89.609373         99.999956       1.000000         31.999985  100.000000
# 2    95.562399         99.999826       0.999998         31.999944   99.969854
# 3    95.502112         99.589598       0.995896         31.868670   99.715433
# 4    99.699506        100.000000       1.000000         31.999999  100.000000
# ..         ...               ...            ...               ...         ...
# 232        NaN               NaN            NaN               NaN         NaN
# 233        NaN               NaN            NaN               NaN         NaN
# 234        NaN               NaN            NaN               NaN         NaN
# 235        NaN               NaN            NaN               NaN         NaN
# 236        NaN               NaN            NaN               NaN         NaN
#
#      norm_water  water_log32_n  calorie  norm_calorie  calorie_log32_n  \
# 0      1.000000      31.999999      1.2      0.984772        31.512690
# 1      1.000000      32.000000      0.4      0.994924        31.837563
# 2      0.999531      31.985007      2.5      0.968274        30.984772
# 3      0.995577      31.858468      2.7      0.965736        30.903553
# 4      1.000000      32.000000      1.1      0.986041        31.553299
# ..          ...            ...      ...           ...              ...
# 232         NaN            NaN      NaN           NaN              NaN
# 233         NaN            NaN      NaN           NaN              NaN
# 234         NaN            NaN      NaN           NaN              NaN
# 235         NaN            NaN      NaN           NaN              NaN
# 236         NaN            NaN      NaN           NaN              NaN
#
#      avg_life  norm_life_expect  norm_pts_log5  lifeexpect_log32_n  \
# 0       82.64          0.926061      29.633939           29.633939
# 1       81.49          0.898182      28.741818           28.741818
# 2       83.06          0.936242      29.959758           29.959758
# 3       82.59          0.924848      29.595152           29.595152
# 4       83.34          0.943030      30.176970           30.176970
# ..        ...               ...            ...                 ...
# 232     72.47          0.679515      21.744485           21.744485
# 233     77.78          0.808242      25.863758           25.863758
# 234     70.08          0.621576      19.890424           19.890424
# 235     67.19          0.551515      17.648485           17.648485
# 236     60.25          0.383273      12.264727           12.264727
#
#      category_a_pts
# 0        156.648659
# 1        156.564726
# 2        155.996409
# 3        155.932623
# 4        155.354630
# ..              ...
# 232             NaN
# 233             NaN
# 234             NaN
# 235             NaN
# 236             NaN
#
# [237 rows x 20 columns]

# %%
pswcl_o.isna('pol_log32_n')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1138], line 1
# ----> 1 pswcl_o.isna('pol_log32_n')
#
# TypeError: DataFrame.isna() takes 1 positional argument but 2 were given

# %%
missing_pol = pswcl_o.loc[pd.isna(pswcl_o['pol_log32_n'])]
missing_san = pswcl_o.loc[pd.isna(pswcl_o['basicsan_log32_n'])]
missing_water = pswcl_o.loc[pd.isna(pswcl_o['water_log32_n'])]
missing_calorie = pswcl_o.loc[pd.isna(pswcl_o['calorie_log32_n'])]
missing_life = pswcl_o.loc[pd.isna(pswcl_o['lifeexpect_log32_n'])]

# %%
missing_pol_vc = missing_pol.value_counts('country_c').reset_index()

# %%
missing_san_vc = missing_san.value_counts('country_c').reset_index()

# %%
missing_water_vc = missing_water.value_counts('country_c').reset_index()
missing_calorie_vc = missing_calorie.value_counts('country_c').reset_index()
missing_life_vc = missing_life.value_counts('country_c').reset_index()

# %%
missing_water_vc.columns = ['country_c', 'missing_water']

# %%
missing_calorie_vc.columns =  ['country_c', 'missing_calorie']

# %%
missing_san_vc.columns =  ['country_c', 'missing_san']

# %%
missing_life_vc.columns =  ['country_c', 'missing_life']

# %%
missing_pol_vc.columns =  ['country_c', 'missing_pol']

# %%
missing_ps = pd.merge(missing_pol_vc, missing_san_vc, on = ['country_c'], how = 'outer')
missing_ps
# Out:
#                     country_c  missing_pol  missing_san
# 0                 Afghanistan            1            1
# 1              American Samoa            1            1
# 2                     Andorra            1            1
# 3                    Anguilla            1            1
# 4         Antigua and Barbuda            1            1
# ..                        ...          ...          ...
# 89                  Venezuela            1            1
# 90  Wallis and Futuna Islands            1            1
# 91             Western Sahara            1            1
# 92                      Yemen            1            1
# 93                   Zimbabwe            1            1
#
# [94 rows x 3 columns]

# %%
missing_psw = pd.merge(missing_ps, missing_water_vc, on = ['country_c'], how = 'outer')

# %%
#missing_psw = missing_psw[['country_c', 'count']]

# %%
missing_pswc = pd.merge(missing_psw, missing_calorie_vc, on = 'country_c', how = 'outer')

# %%
missing_pswcl = pd.merge(missing_pswc, missing_life_vc, on = 'country_c', how = 'outer')

# %%
missing_pswcl = missing_pswcl.fillna(0)

# %%
missing_pswcl['total_missing'] = missing_pswcl['missing_pol'] + missing_pswcl['missing_san'] + missing_pswcl['missing_water'] + missing_pswcl['missing_calorie'] +missing_pswcl['missing_life']

# %%
missing_pswcl = missing_pswcl.sort_values('total_missing', ascending = False)

# %%
missing_pswcl2 = missing_pswcl.loc[missing_pswcl['total_missing'] == 4.0]

# %%
missing_pswcl2
# Out:
#            country_c  missing_pol  missing_san  missing_water  \
# 0        Afghanistan            1            1              1
# 59             Palau            1            1              1
# 68         Singapore            1            1              1
# 67      Saudi Arabia            1            1              1
# 66        San Marino            1            1              1
# ..               ...          ...          ...            ...
# 29         Gibraltar            1            1              1
# 28           Georgia            1            1              1
# 27  French Polynesia            1            1              1
# 26     French Guiana            1            1              1
# 93          Zimbabwe            1            1              1
#
#     missing_calorie  missing_life  total_missing
# 0                 1           0.0            4.0
# 59                1           0.0            4.0
# 68                1           0.0            4.0
# 67                1           0.0            4.0
# 66                1           0.0            4.0
# ..              ...           ...            ...
# 29                1           0.0            4.0
# 28                1           0.0            4.0
# 27                1           0.0            4.0
# 26                1           0.0            4.0
# 93                1           0.0            4.0
#
# [94 rows x 7 columns]

# %% [markdown]
# # Upon double and triple checking, all countries with any missing values at all are missing all 4 of the same values: Pollution, Sanitation, Water, and Calories. None of these countries are missing the life expectancy category.

# %%
missing_pswcl.loc[missing_pswcl['country_c'] == 'Iran']
# Out:
#    country_c  missing_pol  missing_san  missing_water  missing_calorie  \
# 36      Iran            1            1              1                1
#
#     missing_life  total_missing
# 36           0.0            4.0

# %%
pswcl3 = pd.merge(pswc, life, on = 'country_c', how = 'outer')

# %%
pswcl3 = pswcl3[['country_c', 'pm25', 'norm_pol2', 'pol_log32_n', 'safe', 'atleast_basicsan', 'norm_basicsan', 'basicsan_log32_n', 'basicw','norm_water', 'water_log32_n','calorie','norm_calorie', 'calorie_log32_n', 'avg_life','norm_life_expect', 'lifeexpect_log32_n']]

# %%
pswcl3.to_csv('Points_Category_A_Inner_withLife_0416.csv', index=False, header=True)

# %%
pswcl['pswcl_pts'] = pswcl['pol_log32_n'] + pswcl['basicsan_log32_n'] + pswcl['water_log32_n'] + pswcl ['calorie_log32_n'] + pswcl['lifeexpect_log32_n']

# %%
pswcl = pswcl.sort_values('pswcl_pts', ascending = False)

# %%
pswcl2 = pswcl[['country_c', 'pm25','pol_log32_n',
       'atleast_basicsan', 'basicsan_log32_n', 'basicw',
       'norm_water', 'water_log32_n', 'calorie',
      'calorie_log32_n',  'avg_life',
       'lifeexpect_log32_n', 'pswcl_pts']]

# %%
pswcl2.to_csv('Points_Category_A_Complete_withallpts_0416.csv', index=False, header=True)

# %%
pswcl2
# Out:
#                     country_c       pm25  pol_log32_n  atleast_basicsan  \
# 4                      Norway   6.428530    31.502030        100.000002
# 0                     Finland   5.525910    31.985359         99.999956
# 6                   Australia   7.241084    31.066929         99.999826
# 2                      Sweden   6.046158    31.706780         99.589598
# 16                Switzerland   9.935088    29.624362        100.000000
# ..                        ...        ...          ...               ...
# 140                  Cameroon  58.351032     3.698916         17.119519
# 136                     Niger  51.736746     7.240689         24.349297
# 130                      Chad  43.420190    11.693983         17.803308
# 109                  DR Congo  31.912296    17.856153         34.487549
# 101  Central African Republic  28.319962    19.779752         29.900927
#
#      basicsan_log32_n      basicw  norm_water  water_log32_n  calorie  \
# 4           32.000000   99.999999    1.000000      31.999999      1.2
# 0           31.999985  100.000000    1.000000      32.000000      0.4
# 6           31.999944   99.969854    0.999531      31.985007      2.5
# 2           31.868670   99.715433    0.995577      31.858468      2.7
# 16          31.999999  100.000000    1.000000      32.000000      1.1
# ..                ...         ...         ...            ...      ...
# 140          5.478246   67.998398    0.502615      16.083684     31.4
# 136          7.791775   47.412132    0.182653       5.844900     22.9
# 130          5.697058   50.424345    0.229470       7.343054     19.6
# 109         11.036015   35.660282    0.000000       0.000000     62.1
# 101          9.568296   38.380015    0.042271       1.352686     54.1
#
#      calorie_log32_n  avg_life  lifeexpect_log32_n   pswcl_pts
# 4          31.512690     82.64           29.633939  156.648659
# 0          31.837563     81.49           28.741818  156.564726
# 6          30.984772     83.06           29.959758  155.996409
# 2          30.903553     82.59           29.595152  155.932623
# 16         31.553299     83.34           30.176970  155.354630
# ..               ...       ...                 ...         ...
# 140        19.248731     60.95           12.807758   57.317335
# 136        22.700508     59.59           11.752727   55.330599
# 130        24.040609     52.57            6.306909   55.081614
# 109         6.781726     59.71           11.845818   47.519713
# 101        10.030457     44.44            0.000000   40.731192
#
# [143 rows x 13 columns]
