# %%
import pandas as pd
import numpy as np

# %%
slum = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Removed\slums_norm_withbothpts_onlycountries.csv")

# %%
slum
# Out:
#                           country    year  pct_slums  norm_pct_slums  \
# 0                         Germany  2017.0   0.000000        1.000000
# 1                         Denmark  2017.0   0.000000        1.000000
# 2                         Finland  2017.0   0.000000        1.000000
# 3                          France  2017.0   0.000000        1.000000
# 4                         Belgium  2017.0   0.000000        1.000000
# ..                            ...     ...        ...             ...
# 199                   Afghanistan  2017.0  71.210000        0.244055
# 200                         Sudan  2017.0  76.223333        0.190835
# 201  Democratic Republic of Congo  2017.0  77.133333        0.181175
# 202                          Chad  2017.0  82.846667        0.120524
# 203                   South Sudan  2017.0  94.200000        0.000000
#
#      norm_with_pts  norm_log5
# 0         5.000000  32.000000
# 1         5.000000  32.000000
# 2         5.000000  32.000000
# ...

# %%
elec = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\electric_with_allpts_onlycountries.csv")

# %%
hap = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Category_D_E\happiness_20202024.csv")

# %%
gdp = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Category_Misc\GDP_0417.csv")

# %%
r = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Category_D_E\renew_20182022.csv")

# %%
r_corr = r[['country_c', 'renew']]

# %%
gdp_corr = gdp[['country_c', 'gdp']]

# %%
gr_corr = pd.merge(r_corr, gdp_corr, on = 'country_c', how = 'inner')

# %%
gr_corr = gr_corr[['renew', 'gdp']]

# %%
elec_corr = elec[['country', 'access_electricity']]

# %%
gre_corr = pd.merge(gdp_corr, elec, left_on = 'country_c', right_on = 'country',  how = 'inner')

# %%
gre_corr = pd.merge(gre_corr, r_corr, left_on = 'country', right_on = 'country_c',  how = 'inner')

# %%
gre_corr2 = gre_corr[['gdp', 'access_electricity', 'renew']]

# %%
gre_corr2.corr()
# Out:
#                          gdp  access_electricity     renew
# gdp                 1.000000            0.514504 -0.074217
# access_electricity  0.514504            1.000000 -0.196599
# renew              -0.074217           -0.196599  1.000000

# %%
greh = pd.merge(gre_corr, hap, on = 'country', how = 'inner')

# %%
greh2 = greh[['gdp',  'access_electricity',
      'renew', 'happiness']]

# %%
greh_corr = greh2.corr()
type(greh_corr)
# Out:
# pandas.core.frame.DataFrame

# %%
greh.describe()
# Out:
#                 gdp  year_x  access_electricity  norm_access_electricity  \
# count     145.00000   145.0          145.000000               145.000000
# mean    26111.19847  2017.0           84.397806                 0.834627
# std     25445.03219     0.0           25.847816                 0.273970
# min       836.91335  2017.0            8.636364                 0.031605
# 25%      6178.23060  2017.0           78.854545                 0.775872
# 50%     16488.52040  2017.0           99.645455                 0.996242
# 75%     39870.70540  2017.0          100.000000                 1.000000
# max    134529.65000  2017.0          100.000000                 1.000000
#
#        norm_with_pts  norm_pts_log5       renew       year_y   happiness  \
# count     145.000000     145.000000  145.000000   145.000000  145.000000
# mean        4.173135      26.708063   39.274241  2021.982759    5.528409
# std         1.369850       8.767037   31.718248     0.490938    1.123270
# ...

# %%
greh.to_csv('Greh_corr_0417.csv', index=False, header=True)

# %%
un = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Category_B\unemploy_20192023.csv")

# %%
crime = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Category_B\Crime_2024.csv")

# %%
un2 = un[['country_c', 'unem']]

# %%
crime2 = crime[['country_c', 'crime_rate']]

# %%
uc = pd.merge(un2, crime, on = 'country_c',  how = 'inner')

# %%
greh = greh[['country', 'gdp', 'access_electricity',
       'norm_access_electricity','renew', 'happiness']]

# %%
grehuc = pd.merge(greh, uc, on = 'country', how = 'inner')

# %%
grehuc2 = grehuc[[ 'gdp', 'access_electricity',
    'renew',  'happiness', 'unem','crime_rate']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 grehuc2 = grehuc[[ 'gdp', 'access_electricity',
#       2     'renew',  'happiness', 'unem','crime_rate']]
#
# NameError: name 'grehuc' is not defined

# %%
grehuc = grehuc[['country', 'gdp', 'access_electricity', 
       'renew', 'happiness', 'country_c', 'unem', 'crime_rate']]

# %%
func = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Category_B\func_gov_20192023.csv")

# %%
atk = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Category_B\atk_20202021.csv")

# %%
# cat_abcd.corr(numeric_only=True)

# %%
atk2 = atk[['country_c', 'ineq']]

# %%
func2 = func[['country_c', 'gov']]
type(atk2)
# Out:
# pandas.core.frame.DataFrame

# %%
grehuca = pd.merge(grehuc, atk2, on = 'country_c', how = 'inner')

# %%
grehucaf =  pd.merge(grehuca, func2, on = 'country_c', how = 'inner')
grehucaf2 =  pd.merge(grehuca, func2, on = 'country_c', how = 'inner')
grehucaf =grehucaf[[ 'gdp', 'access_electricity',
        'renew',  'happiness', 
        'unem','crime_rate',
        'ineq', 'gov']]

# %%
grehucaf_corr = grehucaf.corr(numeric_only = True)

# %%
grehucaf_corr.to_csv('Grehucaf_corr_0418.csv', index=False, header=True)

# %%
gdp.describe()
quartiles = gdp['gdp'].quantile([0.25, 0.5, 0.75])

gdp_25 = gdp['gdp'].quantile(0.25)
gdp_75 = gdp['gdp'].quantile(0.75)

# %%
lgbt = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Category_C\lgbt_2025.csv")

# %%
s = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Category_C\suicide_2019.csv")

# %%
grehucaf.corr(method = 'spearman')
# Out:
#                          gdp  access_electricity     renew  happiness  \
# gdp                 1.000000            0.885469 -0.085821   0.849496
# access_electricity  0.885469            1.000000 -0.156178   0.734860
# renew              -0.085821           -0.156178  1.000000   0.163654
# happiness           0.849496            0.734860  0.163654   1.000000
# unem               -0.137854           -0.052034  0.047608  -0.242360
# crime_rate         -0.540285           -0.621493  0.132183  -0.346325
# ineq               -0.696946           -0.778425  0.207001  -0.555810
# gov                 0.735510            0.578909  0.152089   0.716706
#
#                         unem  crime_rate      ineq       gov
# gdp                -0.137854   -0.540285 -0.696946  0.735510
# access_electricity -0.052034   -0.621493 -0.778425  0.578909
# renew               0.047608    0.132183  0.207001  0.152089
# happiness          -0.242360   -0.346325 -0.555810  0.716706
# ...

# %%
grehucaf.corr()
# Out:
#                          gdp  access_electricity     renew  happiness  \
# gdp                 1.000000            0.447635 -0.019517   0.722319
# access_electricity  0.447635            1.000000 -0.279353   0.590733
# renew              -0.019517           -0.279353  1.000000   0.094117
# happiness           0.722319            0.590733  0.094117   1.000000
# unem               -0.246056           -0.030809 -0.023603  -0.343854
# crime_rate         -0.509057           -0.368683  0.136517  -0.383963
# ineq               -0.545730           -0.688904  0.258960  -0.548857
# gov                 0.655832            0.379654  0.134390   0.689131
#
#                         unem  crime_rate      ineq       gov
# gdp                -0.246056   -0.509057 -0.545730  0.655832
# access_electricity -0.030809   -0.368683 -0.688904  0.379654
# renew              -0.023603    0.136517  0.258960  0.134390
# happiness          -0.343854   -0.383963 -0.548857  0.689131
# ...

# %%
gdp_25 = gdp['gdp'].quantile(0.25)
gdp_25
# Out:
# 6074.87325

# %%
gdp_25_75 = gdp[(gdp['gdp'] <= gdp_25) | (gdp['gdp'] >= gdp_75)]

#gdp_25 = gdp[(gdp['gdp'] >= gdp_25) & (gdp['gdp'] <= gdp_75)]

# %%
gdp_25_75 = gdp_25_75[['country_c', 'gdp']]

# %%
gdp_25_75.columns = ['country_c', 'gdp2575']

# %%
gdp_25_75
# Out:
#                     country_c       gdp2575
# 0                  Luxembourg  134529.65000
# 1                   Singapore  125350.60300
# 2                       Qatar  112790.94580
# 3                     Ireland  111456.13200
# 4                     Bermuda   94205.03980
# ..                        ...           ...
# 194                Mozambique    1488.11044
# 195                   Somalia    1413.98182
# 196                  DR Congo    1345.89978
# 197  Central African Republic    1136.54042
# 198                   Burundi     836.91335
#
# [100 rows x 2 columns]

# %%
gdp_grehucaf = pd.merge(gdp_25_75, grehucaf2, on = 'country_c', how = 'inner')
gdp_grehucaf.columns
# Out:
# Index(['country_c', 'gdp2575', 'country', 'gdp', 'access_electricity', 'renew',
#        'happiness', 'unem', 'crime_rate', 'ineq', 'gov'],
#       dtype='object')

# %%
gdp_grehucaf = gdp_grehucaf[['country_c', 'gdp2575','access_electricity', 'renew', 'happiness','unem', 'crime_rate','ineq', 'gov']]

# %%
gdp_grehucaf.corr(numeric_only = True)
# Out:
#                      gdp2575  access_electricity     renew  happiness  \
# gdp2575             1.000000            0.702549 -0.188910   0.803795
# access_electricity  0.702549            1.000000 -0.333304   0.772971
# renew              -0.188910           -0.333304  1.000000  -0.159066
# happiness           0.803795            0.772971 -0.159066   1.000000
# unem               -0.294577           -0.035872 -0.010899  -0.341357
# crime_rate         -0.535099           -0.560817  0.196715  -0.604732
# ineq               -0.660778           -0.851852  0.287731  -0.756981
# gov                 0.760342            0.677272 -0.062086   0.862580
#
#                         unem  crime_rate      ineq       gov
# gdp2575            -0.294577   -0.535099 -0.660778  0.760342
# access_electricity -0.035872   -0.560817 -0.851852  0.677272
# renew              -0.010899    0.196715  0.287731 -0.062086
# happiness          -0.341357   -0.604732 -0.756981  0.862580
# ...

# %%
gdp_grehucaf.corr(numeric_only = True, method = 'spearman')
# Out:
#                      gdp2575  access_electricity     renew  happiness  \
# gdp2575             1.000000            0.817567 -0.194648   0.863265
# access_electricity  0.817567            1.000000 -0.325419   0.800428
# renew              -0.194648           -0.325419  1.000000   0.006786
# happiness           0.863265            0.800428  0.006786   1.000000
# unem               -0.127245           -0.049093  0.154035  -0.085408
# crime_rate         -0.492053           -0.603275  0.250344  -0.457303
# ineq               -0.699592           -0.775085  0.196383  -0.708673
# gov                 0.780315            0.768778  0.031585   0.874761
#
#                         unem  crime_rate      ineq       gov
# gdp2575            -0.127245   -0.492053 -0.699592  0.780315
# access_electricity -0.049093   -0.603275 -0.775085  0.768778
# renew               0.154035    0.250344  0.196383  0.031585
# happiness          -0.085408   -0.457303 -0.708673  0.874761
# ...

# %%
hdi = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Category_D_E\hdi_withpts_onlycountries.csv")

# %%
grehucaf.corr()
# Out:
#                          gdp  access_electricity     renew  happiness  \
# gdp                 1.000000            0.447635 -0.019517   0.722319
# access_electricity  0.447635            1.000000 -0.279353   0.590733
# renew              -0.019517           -0.279353  1.000000   0.094117
# happiness           0.722319            0.590733  0.094117   1.000000
# unem               -0.246056           -0.030809 -0.023603  -0.343854
# crime_rate         -0.509057           -0.368683  0.136517  -0.383963
# ineq               -0.545730           -0.688904  0.258960  -0.548857
# gov                 0.655832            0.379654  0.134390   0.689131
#
#                         unem  crime_rate      ineq       gov
# gdp                -0.246056   -0.509057 -0.545730  0.655832
# access_electricity -0.030809   -0.368683 -0.688904  0.379654
# renew              -0.023603    0.136517  0.258960  0.134390
# happiness          -0.343854   -0.383963 -0.548857  0.689131
# ...

# %%
mat = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Removed\maternal_mortality_withallpts_onlycountries.csv")

# %%
mat2 = mat[['country', 'maternal_mortality']]

# %%
grehucafm = pd.merge(grehucaf2, mat, left_on = 'country_c', right_on = 'country', how = 'inner')

# %%
grehucafm = grehucafm[['country_c', 'gdp', 'access_electricity',
       
        'renew',  'happiness', 
       'unem',  'crime_rate',
        'ineq', 'gov',
     'maternal_mortality']]

# %%
grehucafm.corr(numeric_only = True)
# Out:
#                          gdp  access_electricity     renew  happiness  \
# gdp                 1.000000            0.447635 -0.019517   0.722319
# access_electricity  0.447635            1.000000 -0.279353   0.590733
# renew              -0.019517           -0.279353  1.000000   0.094117
# happiness           0.722319            0.590733  0.094117   1.000000
# unem               -0.246056           -0.030809 -0.023603  -0.343854
# crime_rate         -0.509057           -0.368683  0.136517  -0.383963
# ineq               -0.545730           -0.688904  0.258960  -0.548857
# gov                 0.655832            0.379654  0.134390   0.689131
# maternal_mortality -0.465997           -0.703472  0.185456  -0.600843
#
#                         unem  crime_rate      ineq       gov  \
# gdp                -0.246056   -0.509057 -0.545730  0.655832
# access_electricity -0.030809   -0.368683 -0.688904  0.379654
# renew              -0.023603    0.136517  0.258960  0.134390
# ...

# %%
gni = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Removed\gni_withallpts_onlycountries.csv")

# %%
gni2 = gni[['country', 'gni']]

# %%
int = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Removed\internet_withpts_onlycountries.csv")

# %%
food = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Removed\food_insecure_withpts_onlycountries0415.csv")

# %%
food
# Out:
#           country         year  modtosev_food_insecure_pct  \
# 0           Italy  2021.500000                    0.000000
# 1      Kazakhstan  2019.500000                    0.003769
# 2     Switzerland  2018.500000                    0.009968
# 3      Luxembourg  2018.500000                    0.014432
# 4           Japan  2018.500000                    0.017854
# ..            ...          ...                         ...
# 148        Malawi  2018.500000                    0.929726
# 149       Liberia  2018.571429                    0.935359
# 150         Haiti  2020.500000                    0.958738
# 151  Sierra Leone  2018.500000                    0.976443
# 152   South Sudan  2019.500000                    1.000000
#
#      norm_pct_foodinsecure  norm_withpts  norm_withpts_log5  \
# 0                 1.000000      5.000000          32.000000
# 1                 0.996231      4.981155          31.879389
# 2                 0.990032      4.950159          31.681016
# ...

# %%
slum = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Removed\slums_norm_withbothpts_onlycountries.csv")

# %%
child = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Removed\child_mortality_norm_withallpts_onlycountries.csv")

# %%
#grehucafm

grehucafms = pd.merge(grehucafm, slum, left_on = 'country_c', right_on = 'country', how = 'inner')

# %%
grehucafms = grehucafms[['country_c', 'gdp', 'access_electricity', 'renew', 'happiness', 'unem',
       'crime_rate', 'ineq', 'gov', 'maternal_mortality', 
       'pct_slums']]

# %%
grehucafmsc = pd.merge(grehucafms, child, left_on = 'country_c', right_on = 'country', how = 'inner')

# %%
grehucaffmsc = pd.merge(grehucafmsc, food, left_on = 'country_c', right_on = 'country', how = 'inner')

# %%
grehucaffmsc
# Out:
#     country_c_x           gdp  access_electricity      renew  happiness  \
# 0    Luxembourg  134529.65000          100.000000  78.237780     7.2400
# 1     Singapore  125350.60300          100.000000   3.081360     6.5064
# 2       Ireland  111456.13200          100.000000  37.805935     6.9528
# 3        Norway   89001.77000          100.000000  98.489598     7.3272
# 4   Switzerland   81101.41200          100.000000  61.217775     7.2636
# ..          ...           ...                 ...        ...        ...
# 90     Zimbabwe    3246.44688           43.727273  60.725946     3.2162
# 91        Haiti    3150.02492           43.045455  14.719483     3.6150
# 92       Uganda    2713.66026           31.818182  97.653362     4.5008
# 93     Ethiopia    2590.79340           41.481818  99.948256     4.0732
# 94  Afghanistan    2363.04638           87.754545  83.951650     1.9742
#
#        unem  crime_rate      ineq       gov  maternal_mortality  ...  \
# ...

# %%
grehucaffmsci = pd.merge(grehucaffmsc, int, left_on = 'country_c_x', right_on = 'country', how = 'inner')

# %%
grehucaffmsci = pd.merge(grehucaffmsci, gni2, left_on = 'country', right_on = 'country', how = 'inner')

# %%
grehucaffmsci.columns
# Out:
# Index(['country_c_x', 'gdp', 'access_electricity', 'renew', 'happiness',
#        'unem', 'crime_rate', 'ineq', 'gov', 'maternal_mortality', 'pct_slums',
#        'country_x', 'year_x', 'under_5yo_deaths', 'norm_deaths_pct',
#        'norm_with_pts', 'norm_pts_log5', 'country_y', 'year_y',
#        'modtosev_food_insecure_pct', 'norm_pct_foodinsecure', 'norm_withpts',
#        'norm_withpts_log5', 'foodinsecure_log32_n', 'country_c_y', 'index',
#        'country', 'year', 'internet', 'norm_internet', 'norm_internet_log8',
#        'gni'],
#       dtype='object')

# %%
grehucaffmsci = grehucaffmsci[['country', 'gdp', 'access_electricity', 'renew', 'happiness',
       'unem', 'crime_rate', 'ineq', 'gov', 'maternal_mortality', 'pct_slums','under_5yo_deaths', 'modtosev_food_insecure_pct',
        'index','internet','gni']]

# %%
grehucaffmsci.corr(numeric_only = True)
# Out:
#                                  gdp  access_electricity     renew  happiness  \
# gdp                         1.000000            0.445928  0.008134   0.718171
# access_electricity          0.445928            1.000000 -0.216294   0.605237
# renew                       0.008134           -0.216294  1.000000   0.123694
# happiness                   0.718171            0.605237  0.123694   1.000000
# unem                       -0.240605           -0.047336 -0.024685  -0.322743
# crime_rate                 -0.542511           -0.435962  0.101691  -0.452851
# ineq                       -0.533928           -0.634480  0.198927  -0.541343
# gov                         0.668972            0.397115  0.131272   0.753441
# maternal_mortality         -0.466614           -0.749963  0.178432  -0.612468
# pct_slums                  -0.590937           -0.671935  0.136593  -0.690227
# under_5yo_deaths           -0.592442           -0.830403  0.082991  -0.690916
# ...

# %%
grehucaffmsci.corr(numeric_only = True, method = 'spearman')
# Out:
#                                  gdp  access_electricity     renew  happiness  \
# gdp                         1.000000            0.888283 -0.034995   0.858315
# access_electricity          0.888283            1.000000 -0.106611   0.758126
# renew                      -0.034995           -0.106611  1.000000   0.197805
# happiness                   0.858315            0.758126  0.197805   1.000000
# unem                       -0.115244           -0.036612  0.037347  -0.203541
# crime_rate                 -0.592989           -0.665240  0.100873  -0.413090
# ineq                       -0.672550           -0.775155  0.154509  -0.557741
# gov                         0.768630            0.608487  0.155271   0.763101
# maternal_mortality         -0.869093           -0.886959  0.071977  -0.738004
# pct_slums                  -0.838733           -0.830654 -0.016594  -0.781598
# under_5yo_deaths           -0.906172           -0.885989 -0.034127  -0.800279
# ...

# %%
hom = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Removed\homicide_withallpts_onlycountries.csv")

# %%
hom2 = hom[['country', 'homicide_rate']]

# %%
grehhucaffmsci = pd.merge(grehucafms, hom2, left_on = 'country_c', right_on = 'country', how = 'inner')

# %%
grehhucaffmsci = pd.merge(grehhucaffmsci, child, left_on = 'country_c', right_on = 'country', how = 'inner')

# %%
grehhucaffmsci.columns
# Out:
# Index(['country_c', 'gdp', 'access_electricity', 'renew', 'happiness', 'unem',
#        'crime_rate', 'ineq', 'gov', 'maternal_mortality', 'pct_slums',
#        'country_x', 'homicide_rate', 'country_y', 'year', 'under_5yo_deaths',
#        'norm_deaths_pct', 'norm_with_pts', 'norm_pts_log5'],
#       dtype='object')

# %%
grehhucaffmsci = grehhucaffmsci[['country_c', 'gdp', 'access_electricity', 'renew', 'happiness', 'unem',
       'crime_rate', 'ineq', 'gov', 'maternal_mortality', 'pct_slums',
        'homicide_rate', 'under_5yo_deaths']]

# %%
grehhucaffmsci.corr(numeric_only = True)
# Out:
#                          gdp  access_electricity     renew  happiness  \
# gdp                 1.000000            0.452466 -0.008908   0.718752
# access_electricity  0.452466            1.000000 -0.289548   0.593952
# renew              -0.008908           -0.289548  1.000000   0.107457
# happiness           0.718752            0.593952  0.107457   1.000000
# unem               -0.246329           -0.031342 -0.048130  -0.343460
# crime_rate         -0.517215           -0.371671  0.140942  -0.388960
# ineq               -0.545007           -0.688130  0.266701  -0.546934
# gov                 0.661886            0.375566  0.147733   0.691690
# maternal_mortality -0.465481           -0.705816  0.201360  -0.602350
# pct_slums          -0.599763           -0.662096  0.161335  -0.687083
# homicide_rate      -0.320154           -0.107676  0.149376  -0.048665
# under_5yo_deaths   -0.599067           -0.836772  0.145163  -0.687283
#
# ...

# %%
urb = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Category_Misc\share-of-population-urban (1)\share-of-population-urban.csv")

# %%
urb.columns = ['country', 'code', 'year', 'urb_pop']

# %%
urb = urb.loc[urb['year'] >= 2020]

# %%
urb = urb.groupby('country').mean('urb_pop').reset_index()

# %%
urb = urb[['country', 'urb_pop']]

# %%
grehhuucaffmsci = pd.merge(grehhucaffmsci, urb, left_on = 'country_c', right_on = 'country', how = 'inner')

# %%
grehhuucaffmsci = grehhuucaffmsci[['country_c', 'gdp', 'access_electricity', 'renew', 'happiness', 'unem',
       'crime_rate', 'ineq', 'gov', 'maternal_mortality', 'pct_slums',
       'homicide_rate', 'under_5yo_deaths',  'urb_pop']]

# %%
fifteen_varcorr = grehhuucaffmsci.corr(numeric_only = True)

# %%
fifteen_varcorr.to_csv('fifteen_varcorr_0418.csv', index=False, header=True)

# %%
life = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Category_A\LifeExpect_2018.csv")

# %%
grehhuucaffmscil = pd.merge(grehhucaffmsci, life, left_on = 'country_c', right_on = 'country', how = 'inner')

# %%
grehhuucaffmscil.to_csv('sixteen_varcorr_0418.csv', index=False, header=True)

# %%
grehhuucaffmscil = grehhuucaffmscil[['country', 'gdp', 'access_electricity', 'renew', 'happiness',
       'unem', 'crime_rate', 'ineq', 'gov', 'maternal_mortality', 'pct_slums',
       'homicide_rate', 'under_5yo_deaths', 'avg_life']]
grehhuucaffmscil
# Out:
#          country           gdp  access_electricity      renew  happiness  \
# 0     Luxembourg  134529.65000          100.000000  78.237780     7.2400
# 1      Singapore  125350.60300          100.000000   3.081360     6.5064
# 2        Ireland  111456.13200          100.000000  37.805935     6.9528
# 3         Norway   89001.77000          100.000000  98.489598     7.3272
# 4    Switzerland   81101.41200          100.000000  61.217775     7.2636
# ..           ...           ...                 ...        ...        ...
# 102       Rwanda    2772.87118           33.445455  52.864568     3.3415
# 103       Uganda    2713.66026           31.818182  97.653362     4.5008
# 104     Ethiopia    2590.79340           41.481818  99.948256     4.0732
# 105  Afghanistan    2363.04638           87.754545  83.951650     1.9742
# 106   Mozambique    1488.11044           27.181818  82.002480     5.0404
#
#         unem  crime_rate      ineq       gov  maternal_mortality  pct_slums  \
# ...

# %%
sixteen_pearsoncorr = grehhuucaffmscil.corr(numeric_only = True)

# %%
sixteen_spearmancorr = grehhuucaffmscil.corr(numeric_only = True, method = 'spearman')

# %%
sixteen_spearmancorr.to_csv('sixteen_spearmancorr0418.csv', index=False, header=True)

# %%
sixteen_pearsoncorr.to_csv('sixteen_pearsoncorr0418.csv', index=False, header=True)

# %%
sixteen_pearsoncorr
# Out:
#                          gdp  access_electricity     renew  happiness  \
# gdp                 1.000000            0.452466 -0.008908   0.718752
# access_electricity  0.452466            1.000000 -0.289548   0.593952
# renew              -0.008908           -0.289548  1.000000   0.107457
# happiness           0.718752            0.593952  0.107457   1.000000
# unem               -0.246329           -0.031342 -0.048130  -0.343460
# crime_rate         -0.517215           -0.371671  0.140942  -0.388960
# ineq               -0.545007           -0.688130  0.266701  -0.546934
# gov                 0.661886            0.375566  0.147733   0.691690
# maternal_mortality -0.465481           -0.705816  0.201360  -0.602350
# pct_slums          -0.599763           -0.662096  0.161335  -0.687083
# homicide_rate      -0.320154           -0.107676  0.149376  -0.048665
# under_5yo_deaths   -0.599067           -0.836772  0.145163  -0.687283
# ...

# %%
grehhuucaffmscil.to_csv('sixteen_varcorr_0418.csv', index=False, header=True)

# %%
trustgov = pd.read_csv(r"C:\Users\eabro\Downloads\share-who-trust-government\share-who-trust-government.csv")

# %%
trustgov.columns = ['country', 'code', 'year',
       'trust_nat_gov']

# %%
trustgov = trustgov.groupby('country').mean('trust_nat_gov')

# %%
trustgov = trustgov.sort_values('trust_nat_gov', ascending = False).reset_index()

# %%
trustgov.columns
# Out:
# Index(['country', 'year', 'trust_nat_gov'], dtype='object')

# %%
trustgov = trustgov[['country', 'trust_nat_gov']]

# %%
tgrehhuucaffmscil = pd.merge(grehhuucaffmscil, trustgov, on = 'country', how = 'inner')

# %%
tgrehhuucaffmscil
# Out:
#           country           gdp  access_electricity      renew  happiness  \
# 0         Ireland  111456.13200          100.000000  37.805935     6.9528
# 1          Norway   89001.77000          100.000000  98.489598     7.3272
# 2     Switzerland   81101.41200          100.000000  61.217775     7.2636
# 3   United States   71120.37820          100.000000  19.830755     6.8542
# 4     Netherlands   69406.99000          100.000000  27.229993     7.3814
# ..            ...           ...                 ...        ...        ...
# 81         Zambia    3548.96052           37.845455  87.139390     3.8458
# 82       Tanzania    3519.06232           31.572727  35.272242     3.7200
# 83       Zimbabwe    3246.44688           43.727273  60.725946     3.2162
# 84         Uganda    2713.66026           31.818182  97.653362     4.5008
# 85       Ethiopia    2590.79340           41.481818  99.948256     4.0732
#
#       unem  crime_rate      ineq       gov  maternal_mortality  pct_slums  \
# ...

# %%
seventeen = tgrehhuucaffmscil 
seventeen
# Out:
#           country           gdp  access_electricity      renew  happiness  \
# 0         Ireland  111456.13200          100.000000  37.805935     6.9528
# 1          Norway   89001.77000          100.000000  98.489598     7.3272
# 2     Switzerland   81101.41200          100.000000  61.217775     7.2636
# 3   United States   71120.37820          100.000000  19.830755     6.8542
# 4     Netherlands   69406.99000          100.000000  27.229993     7.3814
# ..            ...           ...                 ...        ...        ...
# 81         Zambia    3548.96052           37.845455  87.139390     3.8458
# 82       Tanzania    3519.06232           31.572727  35.272242     3.7200
# 83       Zimbabwe    3246.44688           43.727273  60.725946     3.2162
# 84         Uganda    2713.66026           31.818182  97.653362     4.5008
# 85       Ethiopia    2590.79340           41.481818  99.948256     4.0732
#
#       unem  crime_rate      ineq       gov  maternal_mortality  pct_slums  \
# ...

# %%
eighteen = pd.merge(int, seventeen, on = 'country', how = 'inner')
eighteen
# Out:
#     index      country    year   internet  norm_internet  norm_internet_log8  \
# 0       4  Switzerland  2020.0  46.962643       0.831132            6.649059
# 1       5       France  2020.0  46.323157       0.819815            6.558518
# 2       8      Denmark  2020.0  44.235214       0.782862            6.262899
# 3       9  South Korea  2020.0  43.393286       0.767962            6.143695
# 4      10       Norway  2019.5  43.303817       0.766378            6.131027
# ..    ...          ...     ...        ...            ...                 ...
# 81    186       Zambia  2020.0   0.405331       0.007160            0.057280
# 82    188        Ghana  2020.0   0.351477       0.006207            0.049655
# 83    192     Ethiopia  2019.8   0.244803       0.004319            0.034552
# 84    206       Uganda  2021.0   0.082673       0.001450            0.011597
# 85    214      Nigeria  2020.0   0.040940       0.000711            0.005688
#
# ...

# %%
eighteen.corr(numeric_only = True)
# Out:
#                        index      year  internet  norm_internet  \
# index               1.000000 -0.038943 -0.981314      -0.981314
# year               -0.038943  1.000000  0.075983       0.075983
# internet           -0.981314  0.075983  1.000000       1.000000
# norm_internet      -0.981314  0.075983  1.000000       1.000000
# norm_internet_log8 -0.981314  0.075983  1.000000       1.000000
# gdp                -0.839410  0.045508  0.865360       0.865360
# access_electricity -0.702414 -0.118293  0.596474       0.596474
# renew               0.106584 -0.036816 -0.053398      -0.053398
# happiness          -0.794745 -0.016577  0.785829       0.785829
# unem                0.075947  0.039234 -0.132024      -0.132024
# crime_rate          0.585556 -0.028039 -0.603122      -0.603122
# ineq                0.696259 -0.028277 -0.682461      -0.682461
# gov                -0.689827  0.014419  0.716525       0.716525
# maternal_mortality  0.699151 -0.045891 -0.593202      -0.593202
# ...

# %%
eighteen.to_csv('eighteen_corr_0418.csv', index=False, header=True)

# %%
fifteen_forcor = eighteen[[ 'country', 'internet', 'gdp', 'access_electricity', 'renew', 'happiness',
       'unem', 'crime_rate', 'ineq', 'gov', 'maternal_mortality', 'pct_slums',
       'homicide_rate', 'under_5yo_deaths', 'avg_life', 'trust_nat_gov']]

# %%
subs = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\deaths-from-substance-disorders-who\deaths-from-substance-disorders-who.csv")

# %%
subs.columns = ['country', 'code', 'year', 'substance_abuse']

# %%
subs = subs.loc[subs['year'] >= 2020]

# %%
subs = subs.groupby('country').mean('substance_abuse')

# %%
neighbor = pd.read_csv(r"C:\Users\eabro\Downloads\share-people-trust-neighborhood\share-people-trust-neighborhood.csv")

# %%
neighbor.columns = ['country', 'code', 'year', 'neighbor_trust']

# %%
neighbor = neighbor.groupby('country').mean('neighbor_trust').reset_index()

# %%
sixteen_forcor = pd.merge(fifteen_forcor, neighbor, on = 'country', how = 'inner')

# %%
sixteen_forcor
# Out:
#         country   internet          gdp  access_electricity      renew  \
# 0   Switzerland  46.962643  81101.41200          100.000000  61.217775
# 1        France  46.323157  53983.22600          100.000000  21.977719
# 2       Denmark  44.235214  69255.06000          100.000000  77.999250
# 3   South Korea  43.393286  48497.68700          100.000000   6.228215
# 4        Norway  43.303817  89001.77000          100.000000  98.489598
# ..          ...        ...          ...                 ...        ...
# 81       Zambia   0.405331   3548.96052           37.845455  87.139390
# 82        Ghana   0.351477   6610.83662           78.045455  37.831993
# 83     Ethiopia   0.244803   2590.79340           41.481818  99.948256
# 84       Uganda   0.082673   2713.66026           31.818182  97.653362
# 85      Nigeria   0.040940   5535.29314           56.027273  22.960540
#
#     happiness    unem  crime_rate      ineq       gov  maternal_mortality  \
# ...

# %%
trust_sci = pd.read_csv(r"C:\Users\eabro\Downloads\share-people-trust-science\share-people-trust-science.csv")

# %%
trust_sci = trust_sci.groupby('Entity').mean('Trust science').reset_index()

# %%
trust_sci.columns = ['country', 'year', 'trust_sci']

# %%
seventeen_forcor = pd.merge(trust_sci, sixteen_forcor, on = 'country', how = 'inner')

# %%
seventeen_forcor = seventeen_forcor[['country', 'trust_sci', 'internet', 'gdp',
       'access_electricity', 'renew', 'happiness', 'unem', 'crime_rate',
       'ineq', 'gov', 'maternal_mortality', 'pct_slums', 'homicide_rate',
       'under_5yo_deaths', 'avg_life', 'trust_nat_gov',
       'neighbor_trust']]

# %%
seventeen_forcor.to_csv('seventeen_forcor_0419.csv', index=False, header=True)

# %%
seventeen_forcor.corr(numeric_only = True)
# Out:
#                     trust_sci  internet       gdp  access_electricity  \
# trust_sci            1.000000  0.652951  0.610235            0.452832
# internet             0.652951  1.000000  0.865360            0.596474
# gdp                  0.610235  0.865360  1.000000            0.498353
# access_electricity   0.452832  0.596474  0.498353            1.000000
# renew               -0.081012 -0.053398 -0.018153           -0.341157
# happiness            0.591740  0.785829  0.790958            0.603337
# unem                -0.302116 -0.132024 -0.206178            0.101622
# crime_rate          -0.551481 -0.603122 -0.526501           -0.386811
# ineq                -0.624204 -0.682461 -0.609531           -0.647210
# gov                  0.463236  0.716525  0.716033            0.390696
# maternal_mortality  -0.542805 -0.593202 -0.498310           -0.774998
# pct_slums           -0.499223 -0.757488 -0.669467           -0.671941
# ...

# %%
seventeen.to_csv('seventeen_0419.csv', index=False, header=True)

# %%
seventeen.corr(numeric_only = True)
# Out:
#                          gdp  access_electricity     renew  happiness  \
# gdp                 1.000000            0.498353 -0.018153   0.790958
# access_electricity  0.498353            1.000000 -0.341157   0.603337
# renew              -0.018153           -0.341157  1.000000   0.101800
# happiness           0.790958            0.603337  0.101800   1.000000
# unem               -0.206178            0.101622 -0.016502  -0.208783
# crime_rate         -0.526501           -0.386811  0.094307  -0.371687
# ineq               -0.609531           -0.647210  0.313814  -0.557718
# gov                 0.716033            0.390696  0.132005   0.724618
# maternal_mortality -0.498310           -0.774998  0.183223  -0.520958
# pct_slums          -0.669467           -0.671941  0.155724  -0.655706
# homicide_rate      -0.339864           -0.157465  0.186166  -0.086837
# under_5yo_deaths   -0.633776           -0.848341  0.159474  -0.653051
# ...

# %%
seventeen_forcor2 = pd.merge(trust_sci, seventeen, on = 'country', how = 'inner')

# %%
seventeen_forcor2 = pd.merge(urb, seventeen_forcor2,  on = 'country', how = 'inner')

# %%
seventeen_forcor2.to_csv('seventeen_0419_3pm.csv', index=False, header=True)

# %%
seventeen_forcor2
# Out:
#            country   urb_pop    year  trust_sci          gdp  \
# 0          Algeria  74.50850  2020.0       84.4  14766.34860
# 1        Argentina  92.28750  2020.0       81.4  26307.97260
# 2        Australia  86.42700  2020.0       85.8  57813.82400
# 3          Austria  59.13225  2020.0       89.5  64226.01160
# 4       Bangladesh  39.32675  2020.0       73.5   7485.03102
# ..             ...       ...     ...        ...          ...
# 81  United Kingdom  84.27375  2020.0       92.8  53063.18500
# 82   United States  82.97975  2020.0       88.4  71120.37820
# 83         Uruguay  95.64425  2020.0       83.2  29864.07820
# 84          Zambia  45.47925  2020.0       64.7   3548.96052
# 85        Zimbabwe  32.36425  2020.0       68.0   3246.44688
#
#     access_electricity      renew  happiness     unem  crime_rate      ineq  \
# 0            99.472727   0.902299     5.2546  12.8366        52.2  0.168092
# 1            99.818182  25.430562     6.1010   8.6046        64.2  0.231734
# ...

# %%
press = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\data_grouped\Freedom_Liberties\press-freedom-index-rsf (1)\press-freedom-index-rsf.csv")

# %%
press.columns = ['country', 'code', 'year', 'free_press']

# %%
press = press.loc[press['year'] >=2018]

# %%
press = press.groupby('country').mean('free_press')

# %%
press = press.sort_values('free_press')

# %%
press['norm_press'] = 1 - (press['free_press']   - press['free_press'].min()) / (press['free_press'].max() - press['free_press'] .min())

# %%
press['press_edit'] = press['norm_press'] * 100

# %%
press = press.reset_index()

# %%
press.loc[press['country'] == 'Iceland']
# Out:
#     country    year  free_press  norm_press  press_edit
# 14  Iceland  2019.5      14.825    0.905321   90.532066

# %%
threepm_cor0419 = pd.merge(press, seventeen_forcor2, on = 'country', how = 'inner')

# %%
threepm_cor0419 = threepm_cor0419.drop('year_x', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[614], line 1
# ----> 1 threepm_cor0419 = threepm_cor0419.drop('year_x', axis = 1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
seventeen_forcor2.loc[seventeen_forcor2['country'] == 'Iceland']
# Out:
# Empty DataFrame
# Columns: [country, urb_pop, year, trust_sci, gdp, access_electricity, renew, happiness, unem, crime_rate, ineq, gov, maternal_mortality, pct_slums, homicide_rate, under_5yo_deaths, avg_life, trust_nat_gov]
# Index: []

# %%
apr23corr = pd.merge(threepm_cor0419, press, on = 'country', how = 'inner')

# %%
threepm_cor0419.columns
# Out:
# Index(['country', 'elect_dem_i', 'free_press', 'urb_pop', 'year_y',
#        'trust_sci', 'gdp', 'access_electricity', 'renew', 'happiness', 'unem',
#        'crime_rate', 'ineq', 'gov', 'maternal_mortality', 'pct_slums',
#        'homicide_rate', 'under_5yo_deaths', 'avg_life', 'trust_nat_gov'],
#       dtype='object')

# %%
press
# Out:
#                 year  free_press
# country
# Norway        2019.5      7.5025
# Finland       2019.5      8.2700
# Sweden        2019.5      8.2775
# Netherlands   2019.5      9.5675
# Denmark       2019.5     10.1400
# ...              ...         ...
# Vietnam       2019.5     75.7875
# China         2019.5     78.6025
# Eritrea       2019.5     82.3625
# Turkmenistan  2019.5     83.7775
# North Korea   2019.5     84.8425
#
# [180 rows x 2 columns]

# %%
apr23corr.corr(numeric_only = True)
# Out:
#                     elect_dem_i  free_press_x   urb_pop  year_y  trust_sci  \
# elect_dem_i            1.000000     -0.859393  0.519349     NaN   0.414382
# free_press_x          -0.859393      1.000000 -0.412779     NaN  -0.366929
# urb_pop                0.519349     -0.412779  1.000000     NaN   0.292559
# year_y                      NaN           NaN       NaN     NaN        NaN
# trust_sci              0.414382     -0.366929  0.292559     NaN   1.000000
# gdp                    0.709074     -0.678316  0.517034     NaN   0.610235
# access_electricity     0.414276     -0.251674  0.614115     NaN   0.452832
# renew                  0.206894     -0.333963 -0.171593     NaN  -0.081012
# happiness              0.716192     -0.664157  0.599681     NaN   0.591740
# unem                  -0.002261      0.004923  0.166367     NaN  -0.302116
# crime_rate            -0.309752      0.339713 -0.106640     NaN  -0.551481
# ...

# %%
pat = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\data_grouped\Education\patents.csv")

# %%
pat
# Out:
#                       T29                        Patents Unnamed: 2  \
# 0     Region/Country/Area                            NaN       Year
# 1                       1  Total, all countries or areas       1985
# 2                       1  Total, all countries or areas       1995
# 3                       1  Total, all countries or areas       2005
# 4                       1  Total, all countries or areas       2010
# ...                   ...                            ...        ...
# 1934                  716                       Zimbabwe       2005
# 1935                  716                       Zimbabwe       2010
# 1936                  716                       Zimbabwe       2020
# 1937                  716                       Zimbabwe       2021
# 1938                  716                       Zimbabwe       2022
#
#                       Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                         Series      Value  Footnotes
# ...

# %%
electdem = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\data_grouped\Government\electoral-democracy-index.csv")

# %%
electdem.columns = ['country', 'year', 'elect_dem_i']

# %%
electdem = electdem.loc[electdem['year'] >= 2020]

# %%
electdem = electdem.groupby('country').mean('edi').reset_index()

# %%
threepm_cor0419 = pd.merge(electdem, threepm_cor0419, on = 'country', how = 'inner')

# %%
threepm_cor0419 = threepm_cor0419.drop('year', axis = 1)

# %%
threepm_cor0419
# Out:
#            country  elect_dem_i  free_press   urb_pop  year_y  trust_sci  \
# 0          Algeria       0.2692     45.4150  74.50850  2020.0       84.4
# 1        Argentina       0.7968     28.0300  92.28750  2020.0       81.4
# 2        Australia       0.8476     18.0025  86.42700  2020.0       85.8
# 3          Austria       0.8470     15.3725  59.13225  2020.0       89.5
# 4       Bangladesh       0.2458     49.6100  39.32675  2020.0       73.5
# ..             ...          ...         ...       ...     ...        ...
# 81  United Kingdom       0.8502     22.5000  84.27375  2020.0       92.8
# 82   United States       0.8280     24.3000  82.97975  2020.0       88.4
# 83         Uruguay       0.8456     15.9475  95.64425  2020.0       83.2
# 84          Zambia       0.4662     36.7375  45.47925  2020.0       64.7
# 85        Zimbabwe       0.2860     41.7075  32.36425  2020.0       68.0
#
#             gdp  access_electricity      renew  happiness     unem  \
# ...

# %%
apr23corr = apr23corr[['country', 'elect_dem_i', 'urb_pop', 
       'trust_sci', 'gdp', 'access_electricity', 'renew', 'happiness', 'unem',
       'crime_rate', 'ineq', 'gov', 'maternal_mortality', 'pct_slums',
       'homicide_rate', 'under_5yo_deaths', 'avg_life', 'trust_nat_gov',
        'free_press_y', 'press_edit']]

# %%
apr23corr.to_csv('correlations0423.csv', index=False, header=True)

# %%
apr23corr.loc[apr23corr['country'] == 'Iceland']
# Out:
# Empty DataFrame
# Columns: [country, elect_dem_i, urb_pop, trust_sci, gdp, access_electricity, renew, happiness, unem, crime_rate, ineq, gov, maternal_mortality, pct_slums, homicide_rate, under_5yo_deaths, avg_life, trust_nat_gov, free_press_y, press_edit]
# Index: []

# %%
pts = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\All Categories_Points\new_norms\Category_A_withnorms0420_2pm.csv")

# %%
apr23corr
# Out:
#            country  elect_dem_i   urb_pop  trust_sci          gdp  \
# 0          Algeria       0.2692  74.50850       84.4  14766.34860
# 1        Argentina       0.7968  92.28750       81.4  26307.97260
# 2        Australia       0.8476  86.42700       85.8  57813.82400
# 3          Austria       0.8470  59.13225       89.5  64226.01160
# 4       Bangladesh       0.2458  39.32675       73.5   7485.03102
# ..             ...          ...       ...        ...          ...
# 81  United Kingdom       0.8502  84.27375       92.8  53063.18500
# 82   United States       0.8280  82.97975       88.4  71120.37820
# 83         Uruguay       0.8456  95.64425       83.2  29864.07820
# 84          Zambia       0.4662  45.47925       64.7   3548.96052
# 85        Zimbabwe       0.2860  32.36425       68.0   3246.44688
#
#     access_electricity      renew  happiness     unem  crime_rate  ...  \
# 0            99.472727   0.902299     5.2546  12.8366        52.2  ...
# ...

# %%
apr23corr = pd.merge(pts, apr23corr, left_on = 'country_c', right_on = 'country', how = 'inner')

# %%
apr23corr = apr23corr[['country_c', 'pm25','atleast_basicsan',
        'basicw', 'calorie', 'avg_life_x', 'lifeexpect_log32_n',
       'rank','cat_a_ptsa', 'country', 'elect_dem_i', 'urb_pop',
       'trust_sci', 'gdp', 'access_electricity', 'renew', 'happiness', 'unem',
       'crime_rate', 'ineq', 'gov', 'maternal_mortality', 'pct_slums',
       'homicide_rate', 'under_5yo_deaths', 'trust_nat_gov',
       'free_press_y', 'press_edit']]

# %%
apr23corr.columns = ['country_c', 'pm25', 'atleast_basicsan', 'basicw', 'calorie',
       'avg_life', 'lifeexpect_log32_n', 'a_rank', 'cat_a_ptsa',
       'country', 'elect_dem_i', 'urb_pop', 'trust_sci', 'gdp',
       'access_electricity', 'renew', 'happiness', 'unem', 'crime_rate',
       'ineq', 'gov', 'maternal_mortality', 'pct_slums', 'homicide_rate',
       'under_5yo_deaths', 'trust_nat_gov', 'free_press_y', 'press_edit']

# %%
apr23corr.to_csv('correlations0423.csv', index=False, header=True)

# %%
calc423 = apr23corr.corr(numeric_only = True)

# %%
calc423.to_csv('pearsoncorrelations0423.csv', index=False, header=True)

# %%
calc423_sp = apr23corr.corr(numeric_only = True, method = 'spearman')

# %%
apr23corr.columns =
# Out:
# Index(['country_c', 'pm25', 'atleast_basicsan', 'basicw', 'calorie',
#        'avg_life', 'lifeexpect_log32_n', 'rank', 'cat_a_ptsa', 'country',
#        'elect_dem_i', 'urb_pop', 'trust_sci', 'gdp', 'access_electricity',
#        'renew', 'happiness', 'unem', 'crime_rate', 'ineq', 'gov',
#        'maternal_mortality', 'pct_slums', 'homicide_rate', 'under_5yo_deaths',
#        'trust_nat_gov', 'free_press_y', 'press_edit'],
#       dtype='object')

# %%
b = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\All Categories_Points\new_norms\Category_B_newnorms_0420.csv")

# %%
b2 = b[['country_c',  'terror', 'uhc', 'cat_b_pts', 'rank']]

# %%
b2.columns = ['country_c', 'terror', 'uhc', 'cat_b_pts', 'b_rank']

# %%
corr4231 = pd.merge(apr23corr, b2, on = 'country_c', how = 'inner')

# %%
corr4231 = corr423[['country_c', 'pm25', 'atleast_basicsan', 'basicw', 'calorie',
       'avg_life', 'a_rank', 'cat_a_ptsa',
       'elect_dem_i', 'urb_pop', 'trust_sci', 'gdp', 'access_electricity',
       'renew', 'happiness', 'unem', 'crime_rate', 'ineq', 'gov',
       'maternal_mortality', 'pct_slums', 'homicide_rate', 'under_5yo_deaths',
       'trust_nat_gov', 'free_press_y', 'press_edit', 'terror', 'uhc',
       'cat_b_pts', 'b_rank']]

# %%
corr4231
# Out:
#       country_c       pm25  atleast_basicsan      basicw  calorie  avg_life  \
# 0        Norway   6.428530        100.000002   99.999999      1.2     82.64
# 1       Finland   5.525910         99.999956  100.000000      0.4     81.49
# 2     Australia   7.241084         99.999826   99.969854      2.5     83.06
# 3        Sweden   6.046158         99.589598   99.715433      2.7     82.59
# 4   Switzerland   9.935088        100.000000  100.000000      1.1     83.34
# ..          ...        ...               ...         ...      ...       ...
# 70     Ethiopia  22.111556         16.691721   47.239524     12.6     64.92
# 71       Uganda  31.611022         37.129009   54.348816     38.5     65.44
# 72       Zambia  17.124224         20.755097   66.516028     66.3     62.31
# 73      Nigeria  56.813564         61.586757   74.725992     60.7     52.82
# 74     Cameroon  58.351032         17.119519   67.998398     31.4     60.95
#
# ...

# %%
c = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\All Categories_Points\new_norms\Category C_newnorms_0420.csv")

# %%
c2 = c[['country_c', 'dep_rate', 'school', 'equal_rights',
        'lgbt_eindex', 'sui_rate',
       'cat_c_pts', 'rank']]

# %%
c2.columns = ['country_c', 'dep_rate', 'school', 'equal_rights',
       'lgbt_eindex', 'sui_rate', 'cat_c_pts', 'c_rank']

# %%
corr423 = pd.merge(corr423, c2, on = 'country_c', how = 'inner')

# %%
corr4231.loc[corr4231['country_c'] == 'Iceland']
# Out:
# Empty DataFrame
# Columns: [country_c, pm25, atleast_basicsan, basicw, calorie, avg_life, a_rank, cat_a_ptsa, elect_dem_i, urb_pop, trust_sci, gdp, access_electricity, renew, happiness, unem, crime_rate, ineq, gov, maternal_mortality, pct_slums, homicide_rate, under_5yo_deaths, trust_nat_gov, free_press_y, press_edit, terror, uhc, cat_b_pts, b_rank]
# Index: []
#
# [0 rows x 30 columns]

# %%
threepm_cor0419
# Out:
#            country  elect_dem_i  free_press   urb_pop  year_y  trust_sci  \
# 0          Algeria       0.2692     45.4150  74.50850  2020.0       84.4
# 1        Argentina       0.7968     28.0300  92.28750  2020.0       81.4
# 2        Australia       0.8476     18.0025  86.42700  2020.0       85.8
# 3          Austria       0.8470     15.3725  59.13225  2020.0       89.5
# 4       Bangladesh       0.2458     49.6100  39.32675  2020.0       73.5
# ..             ...          ...         ...       ...     ...        ...
# 81  United Kingdom       0.8502     22.5000  84.27375  2020.0       92.8
# 82   United States       0.8280     24.3000  82.97975  2020.0       88.4
# 83         Uruguay       0.8456     15.9475  95.64425  2020.0       83.2
# 84          Zambia       0.4662     36.7375  45.47925  2020.0       64.7
# 85        Zimbabwe       0.2860     41.7075  32.36425  2020.0       68.0
#
#             gdp  access_electricity      renew  happiness     unem  \
# ...

# %%
all = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\All Categories_Points\new_norms\All_categories_withallrank0423.csv")

# %%
all2 = pd.merge(all,threepm_cor0419, left_on = 'country_c', right_on = 'country', how = 'left')
allcorr = pd.merge(all,threepm_cor0419, left_on = 'country_c', right_on = 'country', how = 'left')

# %%
all2.to_csv('all_0423.csv', index=False, header=True)
allcorr.to_csv('allcorr_0423.csv', index=False, header=True)

# %%
allcorr4 = allcorr.corr(numeric_only = True)
allcorr_sp = allcorr.corr(numeric_only = True, method = 'spearman')

# %%
allcorr = allcorr[[ 'pm25','atleast_basicsan', 'basicw', 'calorie',
       'avg_life_x', 'pswcl_pts', 'rank_x', 'cat_a_ptsa', 'ineq_x',
       'crime_rate_x', 'gov_x',  'terror', 'unem_x',
     'uhc', 'cat_b_pts', 'cat_b_rank', 'dep_rate', 'school',
       'equal_rights', 'lgbt_eindex', 'sui_rate', 
        'cat_c_pts', 'cat_c_rank', 'hdi', 'happiness_x',
       'freedom', 'renew_x', 'research', 'cat_d_pts', 'rank_y', 'hap_420',
       'res_420', 'renew_420', 'freedom_420', 'hdi_420', 'abcd_pts_0421',
       'rank', 'all_rank', 'elect_dem_i', 'free_press', 'urb_pop',
       'trust_sci', 'gdp', 'access_electricity', 'maternal_mortality',
       'pct_slums', 'homicide_rate', 'under_5yo_deaths', 'trust_nat_gov']]

# %%
allcorr = allcorr[['country_c',
 'pm25',
 'atleast_basicsan',
 'basicw',
 'calorie',
 'avg_life_x',
 'pswcl_pts',
 'rank_x',
 'cat_a_ptsa',
 'ineq_x',
 'crime_rate_x',
 'gov_x',
 'norm_gov',
 'terror',
 'norm_terror',
 'unem_x',
 'norm_unemploy',
 'uhc',
 'cat_b_pts',
 'cat_b_rank',
 'dep_rate',
 'school',
 'equal_rights',
 'lgbt_eindex',
 'sui_rate',
 'norm_sui_420',
 'sui_log8_420',
 'cat_c_pts',
 'cat_c_rank',
 'hdi',
 'happiness_x',
 'freedom',
 'renew_x',
 'research',
 'cat_d_pts',
 'rank_y',
 'hap_420',
 'res_420',
 'renew_420',
 'freedom_420',
 'hdi_420',
 'abcd_pts_0421',
 'rank',
 'all_rank',
 'country',
 'elect_dem_i',
 'free_press',
 'urb_pop',
 'year_y',
 'trust_sci',
 'gdp',
 'access_electricity',
 'maternal_mortality',
 'pct_slums',
 'homicide_rate',
 'under_5yo_deaths',
 'trust_nat_gov']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[884], line 1
# ----> 1 allcorr = allcorr[['country_c',
#       2  'pm25',
#       3  'atleast_basicsan',
#       4  'basicw',
#       5  'calorie',
#       6  'avg_life_x',
#       7  'pswcl_pts',
#       8  'rank_x',
#       9  'cat_a_ptsa',
#      10  'ineq_x',
#      11  'crime_rate_x',
#      12  'gov_x',
#      13  'norm_gov',
#      14  'terror',
#      15  'norm_terror',
#      16  'unem_x',
#      17  'norm_unemploy',
#      18  'uhc',
#      19  'cat_b_pts',
#      20  'cat_b_rank',
#      21  'dep_rate',
#      22  'school',
#      23  'equal_rights',
#      24  'lgbt_eindex',
#      25  'sui_rate',
#      26  'norm_sui_420',
#      27  'sui_log8_420',
#      28  'cat_c_pts',
#      29  'cat_c_rank',
#      30  'hdi',
#      31  'happiness_x',
#      32  'freedom',
#      33  'renew_x',
#      34  'research',
# ...

# %%
allcorr3 = allcorr.corr(numeric_only = True)

# %%
allcorr_sp = allcorr_sp.reset_index()
allcorr = allcorr.reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_102776\3901526183.py in ?()
# ----> 1 allcorr_sp = allcorr_sp.reset_index()
#       2 allcorr = allcorr.reset_index()
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6468                     level_values = algorithms.take(
#    6469                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6470                     )
#    6471
# -> 6472                 new_obj.insert(
#    6473                     0,
#    6474                     name,
#    6475                     level_values,
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
# ...

# %%
allcorr = allcorr.corr(numeric_only = True)

# %%
import pandas as pd
from scipy.stats import pearsonr

# Load your data
df = pd.read_csv("your_dataset.csv")

# Choose the two columns you want to test
x = df['GDP_per_capita']
y = df['Happiness_Index']

# Run the Pearson correlation test
r, p_value = pearsonr(x, y)

# Show results
print(f"Correlation coefficient (r): {r}")
print(f"P-value: {p_value}")

# Interpret the results
if p_value < 0.05:
    print("This correlation is statistically significant at the 0.05 level.")
else:
    print("This correlation is NOT statistically significant at the 0.05 level.")

# %%
allcorr = allcorr.reset_index()

# %%
allcorr_sp
# Out:
#     level_0               index      pm25  pol_log32_n  atleast_basicsan  \
# 0         0                pm25  1.000000    -1.000000         -0.471554
# 1         1         pol_log32_n -1.000000     1.000000          0.471554
# 2         2    atleast_basicsan -0.471554     0.471554          1.000000
# 3         3              basicw -0.473502     0.473502          0.999567
# 4         4             calorie  0.467008    -0.467008         -0.998629
# 5         5          avg_life_x -0.499910     0.499910          0.977921
# 6         6           pswcl_pts -0.475234     0.475234          0.997835
# 7         7              rank_x  0.487644    -0.487644         -0.987590
# 8         8          cat_a_ptsa -0.475306     0.475306          0.997763
# 9         9              ineq_x  0.475089    -0.475089         -0.996465
# 10       10        crime_rate_x  0.486562    -0.486562         -0.986147
# 11       11               gov_x -0.998846     0.998846          0.474007
# ...

# %%
allcorr_sp.to_csv('spearmancorrelations0423.csv', index=False, header=True)
allcorr.to_csv('pearsoncorrelations0423.csv', index=False, header=True)

# %%
allcorr.to_csv('pearsoncorrelations0423_1012pm.csv', index=False, header=True)

# %%
# pd.set_option("display.max_rows", None)

# %%
all
# Out:
#       country_c       pm25  pol_log32_n  atleast_basicsan  basicsan_log32_n  \
# 0       Iceland   5.909562    31.779924         98.800000         31.615999
# 1        Norway   6.428530    31.502030        100.000002         32.000000
# 2       Denmark  10.029042    29.574052        100.000001         31.999999
# 3       Finland   5.525910    31.985359         99.999956         31.999985
# 4   Switzerland   9.935088    29.624362        100.000000         31.999999
# ..          ...        ...          ...               ...               ...
# 86       Uganda  31.611022    18.017478         37.129009         11.881283
# 87       Zambia  17.124224    25.774771         20.755097          6.641631
# 88      Nigeria  56.813564     4.522189         61.586757         19.707762
# 89     Cameroon  58.351032     3.698916         17.119519          5.478246
# 90   Mozambique  16.499078    26.109520          4.727668          1.512854
#
# ...

# %%
abcd = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\All Categories_Points\new_norms\All_categories_withallrank0423.csv")

# %%
# !pip install scipy

# %%
from scipy.stats import pearsonr as pr

# %%
allcorr.columns.tolist()
# Out:
# ['country_c',
#  'pm25',
#  'pol_log32_n',
#  'atleast_basicsan',
#  'basicsan_log32_n',
#  'basicw',
#  'norm_water',
#  'water_log32_n',
#  'calorie',
#  'calorie_log32_n',
#  'avg_life_x',
#  'lifeexpect_log32_n',
#  'pswcl_pts',
#  'rank_x',
#  'norm_san',
#  'cat_a_ptsa',
#  'ineq_x',
#  'norm_atk_ineq',
#  'atkineq_log16_n',
#  'crime_rate_x',
#  'norm_crime_rate',
#  'norm_crimerate_log16_n',
#  'gov_x',
#  'norm_gov',
#  'norm_gov_log16_n',
#  'terror',
#  'norm_terror',
#  'terror_log16_n',
#  'unem_x',
#  'norm_unemploy',
#  'unemploy_log16_n',
#  'uhc',
#  'norm_uhc',
#  'uhc_log16',
#  'cat_b_pts',
#  'uhc_log16_n',
#  'cat_b_rank',
#  'dep_rate',
#  'norm_dep_420',
#  'dep_log8_420',
#  'school',
#  'norm_school_420',
#  'school_log8_420',
#  'equal_rights',
#  'norm_eqr_420',
#  'equal_rights_log8_420',
#  'lgbt_eindex',
#  'norm_lgbt_420',
#  'lgbt_eindex_log8_420',
#  'sui_rate',
#  'norm_sui_420',
#  'sui_log8_420',
#  'cat_c_pts',
#  'cat_c_rank',
#  'hdi',
# ...

# %%
subset = allcorr[['maternal_mortality', 'under_5yo_deaths']].dropna()

# %%
s2 = allcorr[['gdp', 'hap_420']].dropna()

# %%
r, p = pearsonr(s2['gdp'], s2['hap_420'])

# %%
from scipy.stats import pearsonr

r, p = pearsonr(subset['maternal_mortality'], subset['under_5yo_deaths'])

# %%
s3 = allcorr[['crime_rate_x', 'freedom_420']]

# %%
s4 = allcorr[['freedom_420', 'hap_420']]

# %%
s5 = allcorr[['sui_rate', 'equal_rights']].dropna()

# %%
r, p = pearsonr(s5['sui_rate'], s5['equal_rights'])

# %%
print(f"r = {r:.3f}, p = {p:.3f}")
# Out:
# r = 0.354, p = 0.001

# %% [markdown]
# from scipy.stats import pearsonr
#
# # Run correlation without country info
# r, p = pearsonr(df['GDP'], df['Happiness'])
#
# # Store or print results
# print(f"r = {r:.3f}, p = {p:.3f}")

# %%
eleven = pd.merge(allcorr, corr2, left_on = 'country', right_on = 'country', how = 'outer')

# %%
corr2 = threepm_cor0419

# %%
corr2 = corr2[['country', 'free_press', 'urb_pop', 
       'trust_sci', 'trust_nat_gov']]

# %%
r, p = pearsonr(subset['maternal_mortality'], subset['under_5yo_deaths'])

# %%
allcorr
# Out:
#          pm25  atleast_basicsan      basicw  calorie  avg_life_x   pswcl_pts  \
# 0    5.909562         98.800000  100.000000      0.4       82.32  125.393331
# 1    6.428530        100.000002   99.999999      1.2       82.64  156.648659
# 2   10.029042        100.000001  100.000000      0.6       81.12  153.785185
# 3    5.525910         99.999956  100.000000      0.4       81.49  156.564726
# 4    9.935088        100.000000  100.000000      1.1       83.34  155.354630
# ..        ...               ...         ...      ...         ...         ...
# 86  31.611022         37.129009   54.348816     38.5       65.44   71.850080
# 87  17.124224         20.755097   66.516028     66.3       62.31   66.701745
# 88  56.813564         61.586757   74.725992     60.7       52.82   57.510773
# 89  58.351032         17.119519   67.998398     31.4       60.95   57.317335
# 90  16.499078          4.727668   57.409623     60.0       60.35   58.416446
#
# ...

# %%
allcorr = allcorr.dropna()

# %%
r, p = pearsonr(allcorr['press_edit'], allcorr['trust_sci'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'press_edit'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1091], line 1
# ----> 1 r, p = pearsonr(allcorr['press_edit'], allcorr['trust_sci'])
#
# ...

# %%
print(f"r = {r:.3f}, p = {p:.3f}")
# Out:
# r = -0.420, p = 0.000

# %%
abcd = pd.merge(abcd, press, left_on = 'country_c', right_on = 'country', how = 'inner')

# %%
abcd.columns.tolist()
# Out:
# ['country_c',
#  'pm25',
#  'pol_log32_n',
#  'atleast_basicsan',
#  'basicsan_log32_n',
#  'basicw',
#  'norm_water',
#  'water_log32_n',
#  'calorie',
#  'calorie_log32_n',
#  'avg_life',
#  'lifeexpect_log32_n',
#  'pswcl_pts',
#  'rank_x',
#  'norm_san',
#  'cat_a_ptsa',
#  'ineq',
#  'norm_atk_ineq',
#  'atkineq_log16_n',
#  'crime_rate',
#  'norm_crime_rate',
#  'norm_crimerate_log16_n',
#  'gov',
#  'norm_gov',
#  'norm_gov_log16_n',
#  'terror',
#  'norm_terror',
#  'terror_log16_n',
#  'unem',
#  'norm_unemploy',
#  'unemploy_log16_n',
#  'uhc',
#  'norm_uhc',
#  'uhc_log16',
#  'cat_b_pts',
#  'uhc_log16_n',
#  'cat_b_rank',
#  'dep_rate',
#  'norm_dep_420',
#  'dep_log8_420',
#  'school',
#  'norm_school_420',
#  'school_log8_420',
#  'equal_rights',
#  'norm_eqr_420',
#  'equal_rights_log8_420',
#  'lgbt_eindex',
#  'norm_lgbt_420',
#  'lgbt_eindex_log8_420',
#  'sui_rate',
#  'norm_sui_420',
#  'sui_log8_420',
#  'cat_c_pts',
#  'cat_c_rank',
#  'hdi',
#  'happiness',
# ...

# %%
abcd[['country_c',
 'pm25',

 'atleast_basicsan',

 'basicw',

 'calorie',

 'avg_life',

 'pswcl_pts',
 'rank_x',

 'cat_a_ptsa',
 'ineq',

 'crime_rate',

 'gov',
 'norm_gov',

 'terror',
 'norm_terror',

 'unem',

 'uhc',

 'cat_b_pts',

 'cat_b_rank',
 'dep_rate',

 'school',

 'equal_rights',
 'norm_eqr_420',

 'lgbt_eindex',

 'sui_rate',

 'cat_c_pts',
 'cat_c_rank',
 'hdi',
 'happiness',
 'freedom',
 'renew',
 'research',
 'cat_d_pts',

 'rank_y',
 'hap_420',
 'res_420',
 'renew_420',
 'freedom_420',
 'hdi_420',
 'abcd_pts_0421',
 'rank',
 'all_rank',
 'press_edit']]
# Out:
#       country_c       pm25  atleast_basicsan      basicw  calorie  avg_life  \
# 0       Iceland   5.909562         98.800000  100.000000      0.4     82.32
# 1        Norway   6.428530        100.000002   99.999999      1.2     82.64
# 2       Denmark  10.029042        100.000001  100.000000      0.6     81.12
# 3       Finland   5.525910         99.999956  100.000000      0.4     81.49
# 4   Switzerland   9.935088        100.000000  100.000000      1.1     83.34
# ..          ...        ...               ...         ...      ...       ...
# 86       Uganda  31.611022         37.129009   54.348816     38.5     65.44
# 87       Zambia  17.124224         20.755097   66.516028     66.3     62.31
# 88      Nigeria  56.813564         61.586757   74.725992     60.7     52.82
# 89     Cameroon  58.351032         17.119519   67.998398     31.4     60.95
# 90   Mozambique  16.499078          4.727668   57.409623     60.0     60.35
#
# ...

# %%
hdi
# Out:
#        year       hdi  norm_hdi  hdi_log4
# 0    2015.0  0.843064  1.000000  4.000000
# 1    2015.0  0.830871  0.983461  3.933844
# 2    2015.0  0.823905  0.974011  3.896044
# 3    2015.0  0.806382  0.950242  3.800967
# 4    2015.0  0.795153  0.935010  3.740041
# ..      ...       ...       ...       ...
# 157  2015.0  0.171893  0.089587  0.358349
# 158  2015.0  0.156142  0.068221  0.272885
# 159  2015.0  0.137999  0.043611  0.174444
# 160  2015.0  0.134231  0.038500  0.154000
# 161  2015.0  0.105848  0.000000  0.000000
#
# [162 rows x 4 columns]
