# %%
import pandas as pd
import numpy as np
import country_converter as coco

# %%
cat_a = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\All Categories_Points\Points_Category_A_Complete_withallpts_0416.csv")
cat_b = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\All Categories_Points\Points_Category_B_final_withpts_0416.csv")

# %%
catab = pd.merge(cat_a, cat_b, on ='country_c', how = 'inner')
catab_o = pd.merge(cat_a, cat_b, on ='country_c', how = 'outer')

# %%
catab = catab[['country_c', 'pm25', 'pol_log32_n', 'atleast_basicsan',
       'basicsan_log32_n', 'basicw', 'water_log32_n', 'calorie',
       'calorie_log32_n', 'avg_life', 'lifeexpect_log32_n', 'pswcl_pts',
       'ineq', 'atkineq_log16_n', 'crime_rate',
        'norm_crime_rate_log16', 'gov',
       'func_gov_pts', 'terror', 'terror_log16_n', 'country',
        'uhc', 'uhc_log16', 'acfth_pts']]

# %%
cat_b
# Out:
#        country_c      ineq  norm_atk_ineq  atkineq_log16_n  crime_rate  \
# 0        Iceland  0.106782       0.913764        14.620218        25.4
# 1        Finland  0.119172       0.892290        14.276635        26.3
# 2    Netherlands  0.126033       0.880397        14.086350        26.3
# 3        Denmark  0.110925       0.906583        14.505320        26.3
# 4         Norway  0.134010       0.866571        13.865141        32.6
# ..           ...       ...            ...              ...         ...
# 115        Yemen  0.231884       0.696933        11.150928        68.6
# 116       Angola  0.557336       0.132851         2.125617        66.5
# 117   Mozambique  0.553966       0.138691         2.219062        63.7
# 118        Haiti  0.520696       0.196356         3.141693        77.9
# 119  Afghanistan  0.292251       0.592303         9.476856        78.3
#
#      norm_crime_rate  norm_crime_rate_log16       gov  norm_gov  func_gov_pts  \
# ...

# %%
cat_c = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\All Categories_Points\Points_Category_C_0416.csv")

# %%
cat_acpts = pd.merge(cat_apts, cat_cpts, on = 'country_c', how = 'inner')
cat_acpts_o = pd.merge(cat_apts, cat_cpts, on = 'country_c', how = 'outer')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 cat_acpts = pd.merge(cat_apts, cat_cpts, on = 'country_c', how = 'inner')
#       2 cat_acpts_o = pd.merge(cat_apts, cat_cpts, on = 'country_c', how = 'outer')
#
# NameError: name 'cat_apts' is not defined

# %%
cat_abcpts = pd.merge(cat_acpts, cat_bpts, on = 'country_c', how = 'inner')
cat_abcpts_o = pd.merge(cat_acpts, cat_bpts, on = 'country_c', how = 'outer')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 cat_abcpts = pd.merge(cat_acpts, cat_bpts, on = 'country_c', how = 'inner')
#       2 cat_abcpts_o = pd.merge(cat_acpts, cat_bpts, on = 'country_c', how = 'outer')
#
# NameError: name 'cat_acpts' is not defined

# %%
cat_apts = cat_a[['country_c', 'pswcl_pts']]
cat_apts_o = cat_a[['country_c', 'pswcl_pts']]

# %%
cat_b.columns
# Out:
# Index(['country_c', 'ineq', 'norm_atk_ineq', 'atkineq_log16_n', 'crime_rate',
#        'norm_crime_rate', 'norm_crime_rate_log16', 'gov', 'norm_gov',
#        'func_gov_pts', 'terror', 'norm_terror', 'terror_log16_n', 'country',
#        'year', 'uhc', 'norm_uhc', 'uhc_log16', 'acfth_pts'],
#       dtype='object')

# %%
cat_bpts = cat_b[['country_c', 'acfth_pts']]
cat_bpts_o = cat_b[['country_c', 'acfth_pts']]

# %%
cat_cpts = cat_c[['country_c', 'dsels_pts']]
cat_cpts_o = cat_c[['country_c', 'dsels_pts']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 cat_cpts = cat_c[['country_c', 'dsels_pts']]
#       2 cat_cpts_o = cat_c[['country_c', 'dsels_pts']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
# ...

# %%
cat_abcpts['abc_pts'] = cat_abcpts['pswcl_pts'] + cat_abcpts['dsels_pts'] + cat_abcpts['acfth_pts']
cat_abcpts_o['abc_pts'] = cat_abcpts['pswcl_pts'] + cat_abcpts['dsels_pts'] + cat_abcpts['acfth_pts']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 cat_abcpts['abc_pts'] = cat_abcpts['pswcl_pts'] + cat_abcpts['dsels_pts'] + cat_abcpts['acfth_pts']
#       2 cat_abcpts_o['abc_pts'] = cat_abcpts['pswcl_pts'] + cat_abcpts['dsels_pts'] + cat_abcpts['acfth_pts']
#
# NameError: name 'cat_abcpts' is not defined

# %%
abc_inner = cat_abcpts.sort_values('abc_pts', ascending = False).reset_index()
abc_outer = cat_abcpts_o.sort_values('abc_pts', ascending = False).reset_index()

# %%
# Top 20 countries for categories A, B, and C combined.
# The United States ranks 26th out of 95 countries.

#abc_outer = abc_outer.sort_values('abc_pts', ascending = False) # this isn't sorting properly- I assume bc of the null values
abc_inner = abc_inner.sort_values('abc_pts', ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 5
#       1 # Top 20 countries for categories A, B, and C combined.
#       2 # The United States ranks 26th out of 95 countries.
#       3
#       4 #abc_outer = abc_outer.sort_values('abc_pts', ascending = False) # this isn't sorting properly- I assume bc of the null values
# ----> 5 abc_inner = abc_inner.sort_values('abc_pts', ascending = False)
#
# NameError: name 'abc_inner' is not defined

# %%
abc_inner
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 abc_inner
#
# NameError: name 'abc_inner' is not defined

# %%
cat_acpts['ac_pts'] = cat_acpts['pswcl_pts'] + cat_acpts['dsels_pts']

# %%
cat_acpts = cat_acpts.sort_values('ac_pts', ascending = False)

# %%
cata_top20 = cat_a.head(20)
catb_top20 = cat_b.head(20)
catc_top20 = cat_c.head(20)

# %%
cata_top20.to_csv('Category_A_Top20.csv', index=False, header=True)

# %%
catb_top20.to_csv('Category_B_Top20.csv', index=False, header=True)

# %%
catc_top20.to_csv('Category_C_Top20.csv', index=False, header=True)

# %%
free = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Category_D_E\free_20202024.csv")
hap = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Category_D_E\happiness_20202024.csv")
hdi = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Category_D_E\hdi_withpts_onlycountries.csv")
plas = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Category_D_E\ocean_plastic_2019.csv")
renew = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\Category_D_E\renew_20182022.csv")

# %%
cat_d = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\All Categories_Points\Category_D_0417.csv")

# %%
free
# Out:
#           country    year  freedom  norm_freedom  freedom_log4_n     country_c
# 0         Denmark  2022.0   0.9850      1.000000        4.000000       Denmark
# 1     Switzerland  2022.0   0.9764      0.991161        3.964645   Switzerland
# 2         Ireland  2022.0   0.9740      0.988695        3.954779       Ireland
# 3         Estonia  2022.0   0.9700      0.984584        3.938335       Estonia
# 4         Belgium  2022.0   0.9686      0.983145        3.932580       Belgium
# ..            ...     ...      ...           ...             ...           ...
# 174         China  2022.0   0.0524      0.041521        0.166084         China
# 175  Turkmenistan  2022.0   0.0392      0.027955        0.111819  Turkmenistan
# 176       Eritrea  2022.0   0.0362      0.024872        0.099486       Eritrea
# 177          Laos  2022.0   0.0340      0.022610        0.090442          Laos
# 178   North Korea  2022.0   0.0120      0.000000        0.000000   North Korea
#
# [179 rows x 6 columns]

# %%
cat_a = cat_a[['country_c', 'pswcl_pts']]
cat_a.columns = ['country_c', 'cat_a_pts']

# %%
cat_b
# Out:
#        country_c      ineq  norm_atk_ineq  atkineq_log16_n  crime_rate  \
# 0        Iceland  0.106782       0.913764        14.620218        25.4
# 1        Finland  0.119172       0.892290        14.276635        26.3
# 2    Netherlands  0.126033       0.880397        14.086350        26.3
# 3        Denmark  0.110925       0.906583        14.505320        26.3
# 4         Norway  0.134010       0.866571        13.865141        32.6
# ..           ...       ...            ...              ...         ...
# 115        Yemen  0.231884       0.696933        11.150928        68.6
# 116       Angola  0.557336       0.132851         2.125617        66.5
# 117   Mozambique  0.553966       0.138691         2.219062        63.7
# 118        Haiti  0.520696       0.196356         3.141693        77.9
# 119  Afghanistan  0.292251       0.592303         9.476856        78.3
#
#      norm_crime_rate  norm_crime_rate_log16       gov  norm_gov  func_gov_pts  \
# ...

# %%
cat_ac
# Out:
#                     country_c   cat_a_pts  cat_c_pts
# 0                      Norway  156.648659  32.169850
# 1                     Finland  156.564726  30.162585
# 2                   Australia  155.996409  29.468990
# 3                      Sweden  155.932623  31.261323
# 4                 Switzerland  155.354630  30.314484
# ..                        ...         ...        ...
# 119                   Nigeria   57.510773  20.724275
# 120                  Cameroon   57.317335  20.780748
# 121                     Niger   55.330599  24.702010
# 122                      Chad   55.081614  16.911304
# 123  Central African Republic   40.731192  15.965707
#
# [124 rows x 3 columns]

# %%
cat_b = cat_b[['country_c', 'acfth_pts']]
cat_b.columns = ['country_c', 'cat_b_pts']

# %%
cat_ac = pd.merge(cat_a, cat_c, on = 'country_c', how = 'inner')

# %%
cat_c
# Out:
#                     country_c  cat_c_pts
# 0                     Germany  33.518719
# 1                     Iceland  33.343828
# 2              United Kingdom  32.840719
# 3                 Netherlands  32.796454
# 4                       Japan  32.795074
# ..                        ...        ...
# 142                    Uganda  16.508103
# 143  Central African Republic  15.965707
# 144                  Eswatini  15.607518
# 145                     Yemen  15.409904
# 146               South Sudan  12.927710
#
# [147 rows x 2 columns]

# %%
cat_c = cat_c[['country_c', 'dselsr_pts']]
cat_c.columns = ['country_c', 'cat_c_pts']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[155], line 1
# ----> 1 cat_c = cat_c[['country_c', 'dselsr_pts']]
#       2 cat_c.columns = ['country_c', 'cat_c_pts']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
# ...

# %%
cat_d = cat_d[['country_c', 'hhfr_pts']]
cat_d.columns = ['country_c', 'cat_d_pts']

# %%
cat_acd = pd.merge(cat_ac, cat_d, on = 'country_c', how = 'inner')
cat_acd
# Out:
#        country_c   cat_a_pts  cat_c_pts  cat_d_pts
# 0         Norway  156.648659  32.169850  15.221052
# 1        Finland  156.564726  30.162585  13.425619
# 2      Australia  155.996409  29.468990  12.089610
# 3         Sweden  155.932623  31.261323  13.728826
# 4    Switzerland  155.354630  30.314484  14.052059
# ..           ...         ...        ...        ...
# 109   Mozambique   58.416446  21.523598   8.472534
# 110      Nigeria   57.510773  20.724275   7.315195
# 111     Cameroon   57.317335  20.780748   7.455846
# 112        Niger   55.330599  24.702010   5.895645
# 113         Chad   55.081614  16.911304   3.968699
#
# [114 rows x 4 columns]

# %%
cat_abcd = pd.merge(cat_acd, cat_b, on = 'country_c', how = 'inner')

# %%
cat_abcd
# Out:
#       country_c       pm25  pol_log32_n  atleast_basicsan  basicsan_log32_n  \
# 0        Norway   6.428530    31.502030        100.000002         32.000000
# 1       Finland   5.525910    31.985359         99.999956         31.999985
# 2     Australia   7.241084    31.066929         99.999826         31.999944
# 3        Sweden   6.046158    31.706780         99.589598         31.868670
# 4   Switzerland   9.935088    29.624362        100.000000         31.999999
# ..          ...        ...          ...               ...               ...
# 86       Rwanda  34.990162    16.208038         13.391745          4.285358
# 87       Zambia  17.124224    25.774771         20.755097          6.641631
# 88   Mozambique  16.499078    26.109520          4.727668          1.512854
# 89      Nigeria  56.813564     4.522189         61.586757         19.707762
# 90     Cameroon  58.351032     3.698916         17.119519          5.478246
#
# ...

# %%
cat_ab = pd.merge(cat_a, cat_b, on = 'country_c', how = 'inner')
cat_ab
# Out:
#        country_c   cat_a_pts  cat_b_pts
# 0         Norway  156.648659  72.241923
# 1        Finland  156.564726  73.301004
# 2      Australia  155.996409  65.678648
# 3         Sweden  155.932623  67.311803
# 4    Switzerland  155.354630  71.766254
# ..           ...         ...        ...
# 96        Zambia   66.701745  36.932076
# 97        Angola   60.068098  28.970642
# 98    Mozambique   58.416446  28.334829
# 99       Nigeria   57.510773  36.582811
# 100     Cameroon   57.317335  29.766817
#
# [101 rows x 3 columns]

# %%
cat_abc = pd.merge(cat_ab, cat_c, on = 'country_c', how = 'inner')

# %%
cat_abcd = pd.merge(cat_abc, cat_d, on = 'country_c', how = 'inner')

# %%
cat_abcd['abcd_pts'] = cat_abcd['cat_a_pts'] + cat_abcd['cat_b_pts'] + cat_abcd['cat_c_pts'] + cat_abcd['cat_d_pts']

# %%
cat_abcd = cat_abcd.sort_values('abcd_pts', ascending = False)

# %%
cat_abcd = cat_abcd.drop_duplicates()

# %%
cat_d = cat_d.groupby('country_c').mean('cat_d_pts').reset_index()

# %%
cat_abcd.to_csv('cat_abcd_final0417.csv', index=False, header=True)

# %%
cat_abcd2 = cat_abcd.reset_index()

# %%
cat_abcd2.loc[cat_abcd2['country_c'] == 'United States']
# Out:
#     index      country_c   cat_a_pts  cat_b_pts  cat_c_pts  cat_d_pts  \
# 21     17  United States  151.957939  58.969049  32.195097   11.16006
#
#       abcd_pts
# 21  254.282146

# %%
cat_abcd2.head(22)
# Out:
#     index       country_c   cat_a_pts  cat_b_pts  cat_c_pts  cat_d_pts  \
# 0       0          Norway  156.648659  72.241923  32.169850  15.221052
# 1       1         Finland  156.564726  73.301004  30.162585  13.425619
# 2       6         Denmark  153.785185  72.321104  32.354814  14.540928
# 3       4     Switzerland  155.354630  71.766254  30.314484  14.052059
# 4       8     Netherlands  153.244516  72.421955  32.796454  11.925467
# 5       3          Sweden  155.932623  67.311803  31.261323  13.728826
# 6       9           Japan  152.941396  70.998712  32.795074  10.900576
# 7       5          Canada  154.716774  67.765536  31.017526  13.626931
# 8      14         Germany  152.345827  68.080101  33.518719  12.627210
# 9      16         Austria  152.007656  68.187190  31.375897  13.640996
# 10      2       Australia  155.996409  65.678648  29.468990  12.089610
# 11     10  United Kingdom  152.917220  63.680058  32.840719  12.161161
# ...

# %%
cat_abcd['rank'] = cat_abcd['abcd_pts'].rank(method='min', ascending=False).astype(int)

# %%
abcd_top25 = cat_abcd.head(25)

# %%
abcd_top25.to_csv('abcd_top25.csv', index=False, header=True)

# %%
cat_d.loc[cat_d['country_c'] == 'United States']
# Out:
#          country_c  cat_d_pts  rank
# 134  United States   11.16006    31

# %%
cat_c.head(10)
# Out:
#         country_c  cat_c_pts  rank
# 0         Germany  33.518719     1
# 1         Iceland  33.343828     2
# 2  United Kingdom  32.840719     3
# 3     Netherlands  32.796454     4
# 4           Japan  32.795074     5
# 5         Ireland  32.417835     6
# 6         Denmark  32.354814     7
# 7   United States  32.195097     8
# 8          Norway  32.169850     9
# 9           Spain  32.052436    10

# %%
cat_a['rank'] = cat_a['cat_a_pts'].rank(method='min', ascending=False).astype(int)
# Out:
# C:\Users\eabro\AppData\Local\Temp\ipykernel_84888\2127414727.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_a['rank'] = cat_a['cat_a_pts'].rank(method='min', ascending=False).astype(int)

# %%
cat_b['rank'] = cat_b['cat_b_pts'].rank(method='min', ascending=False).astype(int)
# Out:
# C:\Users\eabro\AppData\Local\Temp\ipykernel_84888\4156936499.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_b['rank'] = cat_b['cat_b_pts'].rank(method='min', ascending=False).astype(int)

# %%
cat_c['rank'] = cat_c['cat_c_pts'].rank(method='min', ascending=False).astype(int)
# Out:
# C:\Users\eabro\AppData\Local\Temp\ipykernel_84888\1711869524.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_c['rank'] = cat_c['cat_c_pts'].rank(method='min', ascending=False).astype(int)

# %%
cat_d['rank'] = cat_d['cat_d_pts'].rank(method='min', ascending=False).astype(int)

# %%
cat_d
# Out:
#        country_c  cat_d_pts  rank
# 0    Afghanistan   4.511508   132
# 1        Albania  11.210586    28
# 2        Algeria   5.106703   126
# 3      Argentina   9.807422    51
# 4        Armenia   9.052533    57
# ..           ...        ...   ...
# 137    Venezuela   6.980563    92
# 138      Vietnam   5.823551   111
# 139        Yemen   2.795791   142
# 140       Zambia   8.765824    61
# 141     Zimbabwe   5.808067   113
#
# [142 rows x 3 columns]

# %%
gdp = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\gdp-per-capita-worldbank.csv")

# %%
gdp.columns = ['country', 'code', 'year', 'gdp']

# %%
gdp = gdp.loc[gdp['year'] >= 2019]

# %%
gdp = gdp.groupby('country').mean('gdp').reset_index()

# %%
gdp['country_c'] = coco.convert(names= gdp['country'], to='name_short', not_found=None)

# %%
gdp['norm_gdp'] = (gdp['gdp']  - gdp['gdp'] .min()) / (gdp['gdp'] .max() - gdp['gdp'] .min())

# %%
gdp = gdp.sort_values('gdp', ascending = False)

# %%
abcdg = pd.merge(abcd, gdp, on = 'country_c', how = 'inner')

# %%
abcdgdp = abcdg[['gdp', 'all_pts']]

# %%
abcdgdp.corr()
# Out:
#               gdp   all_pts
# gdp      1.000000  0.800092
# all_pts  0.800092  1.000000

# %%
gdp.to_csv('GDP_0417.csv', index=False, header=True)

# %%
cat_b
# Out:
#        country_c  cat_b_pts  rank
# 0        Iceland  74.082487     1
# 1        Finland  73.301004     2
# 2    Netherlands  72.421955     3
# 3        Denmark  72.321104     4
# 4         Norway  72.241923     5
# ..           ...        ...   ...
# 115        Yemen  29.438647   116
# 116       Angola  28.970642   117
# 117   Mozambique  28.334829   118
# 118        Haiti  27.831493   119
# 119  Afghanistan  14.078254   120
#
# [120 rows x 3 columns]

# %%
cat_d = cat_d.sort_values('rank', ascending = True)

# %% [markdown]
# "C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\All Categories_Points\Points_Category_C_0418.csv"

# %%
abcd = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\All Categories_Points\catabcd_0418.csv")

# %%
cate_a = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\All Categories_Points\Points_Category_A_Complete_withallpts_0416.csv")

# %%
cate_a2 = pd.read_csv(r"C:\Users\eabro\Documents\NSS\Python\Projects\Utopia\EmilyBroh_Capstone\emilybroh_capstone\data\All Categories_Points\Points_Category_A_Complete_withallpts_0416.csv")

# %%
cate_a['norm_pm'] = 1 - (cate_a['pm25'] - cate_a['pm25'].min()) / (cate_a['pm25'].max() - cate_a['pm25'].min())
cate_a2['norm_pm'] = 1 - (cate_a2['pm25'] - cate_a2['pm25'].min()) / (cate_a2['pm25'].max() - cate_a2['pm25'].min())

# %%
cate_a = cate_a[['country_c', 'pm25', 'norm_pm', 'pol_log32_n', 'atleast_basicsan',
       'basicsan_log32_n', 'basicw', 'norm_water', 'water_log32_n', 'calorie',
       'calorie_log32_n', 'avg_life', 'lifeexpect_log32_n', 'pswcl_pts',
      ]]

cate_a2 = cate_a2[['country_c', 'pm25', 'norm_pm', 'pol_log32_n', 'atleast_basicsan',
       'basicsan_log32_n', 'basicw', 'norm_water', 'water_log32_n', 'calorie',
       'calorie_log32_n', 'avg_life', 'lifeexpect_log32_n', 'pswcl_pts',
      ]]

# %%
cate_a['norm_san'] = (cate_a['atleast_basicsan'] - cate_a['atleast_basicsan'].min()) / (cate_a['atleast_basicsan'].max() - cate_a['atleast_basicsan'].min())
cate_a2['norm_san'] = (cate_a2['atleast_basicsan'] - cate_a2['atleast_basicsan'].min()) / (cate_a2['atleast_basicsan'].max() - cate_a2['atleast_basicsan'].min())

# %%
cate_a['norm_water'] = (cate_a['basicw'] - cate_a['basicw'].min()) / (cate_a['basicw'].max() - cate_a['basicw'].min())
cate_a2['norm_water'] = (cate_a2['basicw'] - cate_a2['basicw'].min()) / (cate_a2['basicw'].max() - cate_a2['basicw'].min())

# %%
cate_a['norm_calorie'] = 1 - (cate_a['calorie'] - cate_a['calorie'].min()) / (cate_a['calorie'].max() - cate_a['calorie'].min())
cate_a2['norm_calorie'] = 1 - (cate_a2['calorie'] - cate_a2['calorie'].min()) / (cate_a2['calorie'].max() - cate_a2['calorie'].min())

# %%
cata_norms = cate_a[['country_c','norm_pm', 'norm_water','avg_life',
       'norm_san', 'norm_calorie', 'pswcl_pts']]

# %%
cate_a2 = cate_a2[['country_c', 'pm25', 'norm_pm', 'pol_log32_n', 'atleast_basicsan',
       'basicsan_log32_n', 'norm_san', 'basicw', 'norm_water', 'water_log32_n', 'calorie', 'norm_calorie',
       'calorie_log32_n', 'avg_life', 'lifeexpect_log32_n', 'pswcl_pts']]

# %%
cate_a['norm_life'] = (cate_a['avg_life'] - cate_a['avg_life'].min()) / (cate_a['avg_life'].max() - cate_a['avg_life'].min())
cate_a2['norm_life'] = (cate_a2['avg_life'] - cate_a2['avg_life'].min()) / (cate_a2['avg_life'].max() - cate_a2['avg_life'].min())
# Out:
# C:\Users\eabro\AppData\Local\Temp\ipykernel_84888\1213042494.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cate_a2['norm_life'] = (cate_a2['avg_life'] - cate_a2['avg_life'].min()) / (cate_a2['avg_life'].max() - cate_a2['avg_life'].min())

# %%
cate_a = cate_a[['country_c', 'avg_life', 'norm_pm', 'norm_water', 'norm_san', 'norm_calorie', 'norm_life', 'pswcl_pts']]

# %%
cate_a.to_csv('Category_A_withnorms0419.csv', index=False, header=True)

# %%
cate_a
# Out:
#                     country_c       pm25   norm_pm  pol_log32_n  \
# 0                      Norway   6.428530  0.984070    31.502030
# 1                     Finland   5.525910  1.000000    31.985359
# 2                   Australia   7.241084  0.969729    31.066929
# 3                      Sweden   6.046158  0.990818    31.706780
# 4                 Switzerland   9.935088  0.922183    29.624362
# ..                        ...        ...       ...          ...
# 138                  Cameroon  58.351032  0.067695     3.698916
# 139                     Niger  51.736746  0.184430     7.240689
# 140                      Chad  43.420190  0.331208    11.693983
# 141                  DR Congo  31.912296  0.534309    17.856153
# 142  Central African Republic  28.319962  0.597710    19.779752
#
#      atleast_basicsan  basicsan_log32_n      basicw  norm_water  \
# 0          100.000002         32.000000   99.999999    1.000000
# 1           99.999956         31.999985  100.000000    1.000000
# ...

# %%
cate_a2['rank'] = cate_a2['pswcl_pts'].rank(ascending = False)
# Out:
# C:\Users\eabro\AppData\Local\Temp\ipykernel_84888\2871838228.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cate_a2['rank'] = cate_a2['pswcl_pts'].rank(ascending = False)

# %%
cate_a2
# Out:
#                     country_c       pm25   norm_pm  pol_log32_n  \
# 0                      Norway   6.428530  0.984070    31.502030
# 1                     Finland   5.525910  1.000000    31.985359
# 2                   Australia   7.241084  0.969729    31.066929
# 3                      Sweden   6.046158  0.990818    31.706780
# 4                 Switzerland   9.935088  0.922183    29.624362
# ..                        ...        ...       ...          ...
# 138                  Cameroon  58.351032  0.067695     3.698916
# 139                     Niger  51.736746  0.184430     7.240689
# 140                      Chad  43.420190  0.331208    11.693983
# 141                  DR Congo  31.912296  0.534309    17.856153
# 142  Central African Republic  28.319962  0.597710    19.779752
#
#      atleast_basicsan  basicsan_log32_n  norm_san      basicw  norm_water  \
# 0          100.000002         32.000000  1.000000   99.999999    1.000000
# ...

# %%
cate_a2.to_csv('Category_A_withallrank0419.csv', index=False, header=True)

# %%
cat_b.crime_rate.max()
# Out:
# 81.2

# %%
cat_d
# Out:
#        country_c  cat_d_pts  rank
# 55       Iceland  15.348448     1
# 97        Norway  15.221052     2
# 33       Denmark  14.540928     3
# 93   New Zealand  14.312879     4
# 121  Switzerland  14.052059     5
# ..           ...        ...   ...
# 22          Chad   3.968699   138
# 9     Bangladesh   3.931982   139
# 7     Azerbaijan   3.789820   140
# 36         Egypt   3.589325   141
# 139        Yemen   2.795791   142
#
# [142 rows x 3 columns]

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[745], line 1
# ----> 1 c
#
# NameError: name 'c' is not defined

# %%
abcd
# Out:
#       country_c   cat_a_pts  cat_b_pts  cat_c_pts       hdi  happiness  \
# 0        Norway  156.648659  72.241923  32.169850  0.841248     7.3272
# 1       Finland  156.564726  73.301004  30.162585  0.789771     7.7888
# 2       Denmark  153.785185  72.321104  32.354814  0.800761     7.5892
# 3   Switzerland  155.354630  71.766254  30.314484  0.885545     7.2636
# 4   Netherlands  153.244516  72.421955  32.796454  0.769788     7.3814
# ..          ...         ...        ...        ...       ...        ...
# 86       Uganda   71.850080  38.721159  16.508103  0.259619     4.5008
# 87       Zambia   66.701745  36.932076  19.333568  0.282741     3.8458
# 88      Nigeria   57.510773  36.582811  20.724275  0.291562     4.8116
# 89   Mozambique   58.416446  28.334829  21.523598  0.232508     5.0404
# 90     Cameroon   57.317335  29.766817  20.780748  0.220729     4.9848
#
#     freedom      renew  hhfrr_pts  rank     all_pts
# 0    0.9436  98.489598  15.310198     1  276.370631
# ...

# %%
cat_a
# Out:
#                     country_c       pm25  pol_log32_n  atleast_basicsan  \
# 0                      Norway   6.428530    31.502030        100.000002
# 1                     Finland   5.525910    31.985359         99.999956
# 2                   Australia   7.241084    31.066929         99.999826
# 3                      Sweden   6.046158    31.706780         99.589598
# 4                 Switzerland   9.935088    29.624362        100.000000
# ..                        ...        ...          ...               ...
# 138                  Cameroon  58.351032     3.698916         17.119519
# 139                     Niger  51.736746     7.240689         24.349297
# 140                      Chad  43.420190    11.693983         17.803308
# 141                  DR Congo  31.912296    17.856153         34.487549
# 142  Central African Republic  28.319962    19.779752         29.900927
#
#      basicsan_log32_n      basicw  norm_water  water_log32_n  calorie  \
# ...

# %% [markdown]
# # I'm replacing Iceland's value here.  The data set erroneously has Iceland's % of pop without basic sanitation as 1.2%.
# # Upon checking the map on OurWorldinData.com, it labels Iceland as having 98.2% of people having basic sanitation.

# %%
cat_a.loc[cat_a['country_c'] == 'Iceland']
# Out:
#    country_c      pm25  pol_log32_n  atleast_basicsan  basicsan_log32_n  \
# 68   Iceland  5.909562    31.779924              98.8          0.390147
#
#     basicw  norm_water  water_log32_n  calorie  calorie_log32_n  avg_life  \
# 68   100.0         1.0           32.0      0.4        31.837563     82.32
#
#     lifeexpect_log32_n   pswcl_pts  rank  norm_san
# 68           29.385697  125.393331  69.0     0.988

# %%
cat_a['norm_san'] = (cat_a['atleast_basicsan']  - cat_a['atleast_basicsan'].min()) / (cat_a['atleast_basicsan'].max() - cat_a['atleast_basicsan'].min())

# %%
cat_a['basicsan_log32_n'] = cat_a['norm_san'] * 32

# %%
cat_a.loc[cat_a["country_c"] == "Iceland", "atleast_basicsan"] = 98.8

# %%
cat_a['cat_a_ptsa'] = cat_a['pswcl_pts']

# %%
cat_a['cat_a_ptsa'] = cat_a['pol_log32_n'] + cat_a['basicsan_log32_n'] + cat_a['water_log32_n'] + cat_a['calorie_log32_n'] + cat_a['lifeexpect_log32_n']

# %%
cat_a['rank'] = cat_a['cat_a_ptsa'].rank(ascending = False)
cat_a
# Out:
#                     country_c       pm25  pol_log32_n  atleast_basicsan  \
# 0                      Norway   6.428530    31.502030        100.000002
# 1                     Finland   5.525910    31.985359         99.999956
# 2                   Australia   7.241084    31.066929         99.999826
# 3                      Sweden   6.046158    31.706780         99.589598
# 4                 Switzerland   9.935088    29.624362        100.000000
# ..                        ...        ...          ...               ...
# 138                  Cameroon  58.351032     3.698916         17.119519
# 139                     Niger  51.736746     7.240689         24.349297
# 140                      Chad  43.420190    11.693983         17.803308
# 141                  DR Congo  31.912296    17.856153         34.487549
# 142  Central African Republic  28.319962    19.779752         29.900927
#
#      basicsan_log32_n      basicw  norm_water  water_log32_n  calorie  \
# ...

# %%
cat_a.to_csv('Category_A_withnorms0420_2pm.csv', index=False, header=True)

# %%
cat_a3 = cat_a[['country_c',
# Out:
#                     country_c       pm25  pol_log32_n  atleast_basicsan  \
# 0                      Norway   6.428530    31.502030        100.000002
# 1                     Finland   5.525910    31.985359         99.999956
# 2                   Australia   7.241084    31.066929         99.999826
# 3                      Sweden   6.046158    31.706780         99.589598
# 4                 Switzerland   9.935088    29.624362        100.000000
# ..                        ...        ...          ...               ...
# 138                  Cameroon  58.351032     3.698916         17.119519
# 139                     Niger  51.736746     7.240689         24.349297
# 140                      Chad  43.420190    11.693983         17.803308
# 141                  DR Congo  31.912296    17.856153         34.487549
# 142  Central African Republic  28.319962    19.779752         29.900927
#
#      basicsan_log32_n      basicw  norm_water  water_log32_n  calorie  \
# ...

# %%
abcd
# Out:
#       country_c   cat_a_pts  cat_b_pts  cat_c_pts       hdi  happiness  \
# 0        Norway  156.648659  72.241923  32.169850  0.841248     7.3272
# 1       Finland  156.564726  73.301004  30.162585  0.789771     7.7888
# 2       Denmark  153.785185  72.321104  32.354814  0.800761     7.5892
# 3   Switzerland  155.354630  71.766254  30.314484  0.885545     7.2636
# 4   Netherlands  153.244516  72.421955  32.796454  0.769788     7.3814
# ..          ...         ...        ...        ...       ...        ...
# 86       Uganda   71.850080  38.721159  16.508103  0.259619     4.5008
# 87       Zambia   66.701745  36.932076  19.333568  0.282741     3.8458
# 88      Nigeria   57.510773  36.582811  20.724275  0.291562     4.8116
# 89   Mozambique   58.416446  28.334829  21.523598  0.232508     5.0404
# 90     Cameroon   57.317335  29.766817  20.780748  0.220729     4.9848
#
#     freedom      renew  hhfrr_pts  rank     all_pts
# 0    0.9436  98.489598  15.310198     1  276.370631
# ...

# %%
abcd['norm_san'] = (abcd['atleast_basicsan']  - abcd['atleast_basicsan'].min()) / (abcd['atleast_basicsan'].max() - abcd['atleast_basicsan'].min())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'atleast_basicsan'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[818], line 1
# ...

# %%
cat_abcd
# Out:
#       country_c   cat_a_pts  cat_b_pts  cat_c_pts  cat_d_pts    abcd_pts  rank
# 0        Norway  156.648659  72.241923  32.169850  15.221052  276.281484     1
# 1       Finland  156.564726  73.301004  30.162585  13.425619  273.453934     2
# 6       Denmark  153.785185  72.321104  32.354814  14.540928  273.002031     3
# 4   Switzerland  155.354630  71.766254  30.314484  14.052059  271.487427     4
# 8   Netherlands  153.244516  72.421955  32.796454  11.925467  270.388393     5
# ..          ...         ...        ...        ...        ...         ...   ...
# 84       Uganda   71.850080  38.721159  16.508103   8.640045  135.719387    86
# 86       Zambia   66.701745  36.932076  19.333568   8.765824  131.733213    87
# 88      Nigeria   57.510773  36.582811  20.724275   7.315195  122.133054    88
# 87   Mozambique   58.416446  28.334829  21.523598   8.472534  116.747406    89
# 89     Cameroon   57.317335  29.766817  20.780748   7.455846  115.320744    90
#
# [90 rows x 7 columns]

# %%
abc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[832], line 1
# ----> 1 abc
#
# NameError: name 'abc' is not defined
